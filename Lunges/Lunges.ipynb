# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("1.csv")
df.drop(["image_id","category_id","score"], axis = 1)
df["keypoints"].to_numpy()
a = np.array(df["keypoints"])
b = int(len(df)/51)
a2 = a.reshape(b,51)
a1 = pd.DataFrame(a2)
a3 =a1.rename(columns={0:'nose_x',1:'nose_y',2:'nose_s',3:'lEye_x',4:'lEye_y',5:'lEye_s',6:'rEye_x',7:'rEye_y',8:'rEye_s',9:'lEar_x',10:'lEar_y',
                       11:'lEar_s',12:'rEar_x',13:'rEar_y',14:'rEar_s',15:'lShoulder_x',16:'lShoulder_y',17:'lShoulder_s',18:'rShoulder_x',19:'rShoulder_y',20:'rShoulder_s',
                       21:'lElbow_x',22:'lElbow_y',23:'lElbow_s',24:'rElbow_x',25:'rElbow_y',26:'rElbow_s',27:'lWrist_x',28:'lWrist_y',29:'lWrist_s',30:'rWrist_x',
                       31:'rWrist_y',32:'rWrist_s',33:'lHip_x',34:'lHip_y',35:'lHip_s',36:'rHip_x',37:'rHip_y',38:'rHip_s',39:'lKnee_x',40:'lKnee_y',
                       41:'lKnee_s',42:'rKnee_x',43:'rKnee_y',44:'rKnee_s',45:'lAnkle_x',46:'lAnkle_y',47:'lAnkle_s',48:'rAnkle_x',49:'rAnkle_y',50:'rAnkle_s'})
a3
a3.to_csv("lunges.csv", index = False)

# %%
df = pd.read_csv("lunges.csv")
pd.set_option('display.max_columns', None)
df
# Out:
#          nose_x      nose_y    nose_s      lEye_x      lEye_y    lEye_s  \
# 0    537.818787  286.350616  0.915342  573.800110  262.363129  0.923594
# 1    523.323181  298.344360  0.908454  559.304382  262.363129  0.924344
# 2    521.430054  298.344360  0.885651  545.417542  262.363129  0.931664
# 3    501.398376  298.344360  0.901590  537.379578  262.363129  0.922680
# 4    492.274109  298.344360  0.902404  528.255371  262.363129  0.929057
# ..          ...         ...       ...         ...         ...       ...
# 482  533.210876  252.295181  0.899008  553.499634  232.006424  0.911650
# 483  535.636536  260.191315  0.904383  555.751709  230.018570  0.933272
# 484  534.858887  250.582489  0.903421  555.010132  230.431290  0.920396
# 485  534.824829  251.222702  0.881558  565.128723  231.020096  0.934201
# 486  545.699402  252.554092  0.878742  566.008972  232.244522  0.953248
#
#          rEye_x      rEye_y    rEye_s      lEar_x      lEar_y    lEar_s  \
# 0    501.837524  262.363129  0.894491  621.775085  286.350616  0.907541
# 1    499.335632  262.363129  0.920780  607.279480  298.344360  0.904176
# 2    485.448792  262.363129  0.917084  605.386353  298.344360  0.887457
# 3    465.417114  262.363129  0.897875  597.348389  298.344360  0.880633
# 4    456.292847  262.363129  0.905823  588.224182  298.344360  0.866475
# ..          ...         ...       ...         ...         ...       ...
# 482  502.777710  232.006424  0.908584  594.077148  252.295181  0.879233
# 483  505.463806  230.018570  0.897181  595.981995  260.191315  0.877918
# 484  504.632111  230.431290  0.921223  595.312500  250.582489  0.875900
# 485  504.520905  231.020096  0.922736  605.533997  251.222702  0.868377
# 486  515.235046  232.244522  0.907832  606.628113  252.554092  0.856055
#
#          rEar_x      rEar_y    rEar_s  lShoulder_x  lShoulder_y  lShoulder_s  \
# 486  281.675049  465.804596  0.796041  586.318542   831.376770  0.745652
#
#          rHip_x       rHip_y    rHip_s     lKnee_x      lKnee_y   lKnee_s  \
# 0    441.868774   958.000671  0.776582  657.756348  1161.894409  0.822379
# 1    439.366882   981.988220  0.748331  655.254456  1161.894409  0.800618
# 2    425.480042   993.981934  0.755696  653.361389  1185.881836  0.798840
# 3    417.442078  1005.975708  0.759823  645.323425  1209.869385  0.803679
# 4    408.317871  1005.975708  0.767481  648.192932  1197.875610  0.825795
# ..          ...          ...       ...         ...          ...       ...
# 482  431.766968   830.525208  0.755105  594.077148  1104.423584  0.848804
# 483  425.003174   833.473328  0.761382  595.981995  1105.027954  0.856856
# 484  434.102875   834.967468  0.749536  595.312500  1096.933105  0.856030
# 485  433.811676   826.997681  0.731920  595.432678  1089.631714  0.838381
# 486  433.996857   831.376770  0.728658  586.318542  1085.246338  0.861764
#
#         rKnee_x      rKnee_y   rKnee_s    lAnkle_x     lAnkle_y  lAnkle_s  \
# 0    369.906311  1305.819336  0.806748  621.775085  1305.819336  0.829023
# 1    367.404419  1317.813110  0.827927  619.273193  1305.819336  0.829984
# 2    353.517578  1329.806885  0.796857  629.373840  1317.813110  0.871903
# 3    345.479614  1329.806885  0.802571  621.335876  1305.819336  0.813307
# 4    336.355347  1341.800659  0.801180  624.205383  1305.819336  0.813374
# ..          ...          ...       ...         ...          ...       ...
# 482  431.766968  1104.423584  0.863813  563.644043  1287.022461  0.825653
# 483  425.003174  1094.970337  0.834242  565.809265  1286.064453  0.825137
# 484  434.102875  1086.857422  0.866838  565.085693  1288.369629  0.866255
# 485  433.811676  1089.631714  0.846209  565.128723  1291.657959  0.843106
# 486  433.996857  1085.246338  0.881638  555.854187  1298.496826  0.823818
#
#        rAnkle_x     rAnkle_y  rAnkle_s
# 0    321.931274  1701.613037  0.814752
# 1    319.429382  1701.613037  0.791999
# 2    317.536316  1713.606812  0.780354
# 3    309.498352  1725.600586  0.781385
# 4    300.374084  1737.594238  0.787823
# ..          ...          ...       ...
# 482  452.055786  1307.311157  0.867188
# 483  445.118347  1306.179565  0.856774
# 484  444.178497  1298.445068  0.837787
# 485  443.912994  1301.759277  0.851102
# 486  444.151642  1298.496826  0.854430
#
# [487 rows x 51 columns]

# %%
df['rLowerLegLen']=((df['rKnee_x']-df['rAnkle_x'])**2+(df['rKnee_y']-df['rAnkle_y'])**2)**.5
df['rLowerLegAng']=np.arctan2((df['rKnee_y']-df['rAnkle_y']),(df['rKnee_x']-df['rAnkle_x']))*180/3.14
df['rLowerLegScr']=(df['rKnee_s']*df['rAnkle_s'])**.5
df['lLowerLegLen']=((df['lKnee_x']-df['lAnkle_x'])**2+(df['lKnee_y']-df['lAnkle_y'])**2)**.5
df['lLowerLegAng']=np.arctan2((df['lKnee_y']-df['lAnkle_y']),(df['lKnee_x']-df['lAnkle_x']))*180/3.14
df['lLowerLegScr']=(df['lKnee_s']*df['lAnkle_s'])**.5
df['lUpperLegLen']=((df['lHip_x']-df['lKnee_x'])**2+(df['lHip_y']-df['lKnee_y'])**2)**.5
df['lUpperLegAng']=np.arctan2((df['lHip_y']-df['lKnee_y']),(df['lHip_x']-df['lKnee_x']))*180/3.14
df['lUpperLegScr']=(df['lKnee_s']*df['lHip_s'])**.5
df['rUpperLegLen']=((df['rHip_x']-df['rKnee_x'])**2+(df['rHip_y']-df['rKnee_y'])**2)**.5
df['rUpperLegAng']=np.arctan2((df['rHip_y']-df['rKnee_y']),(df['rHip_x']-df['rKnee_x']))*180/3.14
df['rUpperLegScr']=(df['rKnee_s']*df['rHip_s'])**.5

# %%
df['rBackLen']=((df['rHip_x']-df['rShoulder_x'])**2+(df['rHip_y']-df['rShoulder_y'])**2)**.5
df['rBackAng']=np.arctan2((df['rShoulder_y']-df['rHip_y']),(df['rShoulder_x']-df['rHip_x']))*180/3.14
df['rBackScr']=(df['rHip_s']*df['rShoulder_s'])**.5
df['lBackLen']=((df['lHip_x']-df['lShoulder_x'])**2+(df['lHip_y']-df['lShoulder_y'])**2)**.5
df['lBackAng']=np.arctan2((df['lShoulder_y']-df['lHip_y']),(df['lShoulder_x']-df['lHip_x']))*180/3.14
df['lBackScr']=(df['lHip_s']*df['lShoulder_s'])**.5
df['mBackLen']=((((df['rHip_x']+df['lHip_x'])/2)-df['nose_x'])**2+(((df['rHip_y']+df['lHip_y'])/2)-df['nose_y'])**2)**.5
df['mBackAng']=np.arctan2((df['nose_y']-((df['rHip_y']+df['lHip_y'])/2)),(df['nose_x']-((df['rHip_x']+df['lHip_x'])/2)))*180/3.14
df['mBackScr']=(((df['lHip_s']*df['lHip_s'])**.5)*df['nose_s'])**.5

# %%
df['bodyLen']=((((df['rAnkle_x']+df['lAnkle_x'])/2)-df['nose_x'])**2+(((df['rAnkle_y']+df['lAnkle_y'])/2)-df['nose_y'])**2)**.5
df['bodyAng']=np.arctan((df['nose_y']-((df['rAnkle_y']+df['lAnkle_y'])/2))/(df['nose_x']-((df['rAnkle_x']+df['lAnkle_x'])/2)))*180/3.14
df['bodykScr']=(((df['lAnkle_s']*df['lAnkle_s'])**.5)*df['nose_s'])**.5

# %%
df=df
df=df.drop(columns=['rElbow_s', 'rWrist_s', 'lElbow_s', 'lWrist_s', 'rEye_s', 'lEye_s', 'rEar_s', 'lEar_s'])
df.head(20)
# Out:
#         nose_x      nose_y    nose_s      lEye_x      lEye_y      rEye_x  \
# 0   537.818787  286.350616  0.915342  573.800110  262.363129  501.837524
# 1   523.323181  298.344360  0.908454  559.304382  262.363129  499.335632
# 2   521.430054  298.344360  0.885651  545.417542  262.363129  485.448792
# 3   501.398376  298.344360  0.901590  537.379578  262.363129  465.417114
# 4   492.274109  298.344360  0.902404  528.255371  262.363129  456.292847
# 5   486.670715  286.350616  0.878119  510.658264  250.369354  450.689514
# 6   473.909515  274.356873  0.877366  509.890778  250.369354  437.928253
# 7   469.476135  262.363129  0.918335  505.457397  238.375610  433.494873
# 8   459.894470  262.363129  0.930106  495.875732  238.375610  435.906982
# 9   461.325928  262.363129  0.931606  497.307190  238.375610  425.344727
# 10  459.917145  262.363129  0.932349  495.898407  238.375610  423.935883
# 10 -92.355884  0.808594  1241.483418  89.214912  0.797637
# 11 -91.939997  0.790398  1223.597576  88.921776  0.718715
# 12 -92.432804  0.764521  1211.606160  88.910652  0.685162
# 13 -92.452840  0.763603  1199.749685  88.612827  0.660065
# 14 -93.008089  0.803697  1152.164936  87.956606  0.571181
# 15 -92.021589  0.770269  1121.816440  88.513262  0.637801
# 16 -91.608670  0.791668  1091.579509  89.100818  0.614094
# 17 -91.608670  0.816528  1061.599291  89.074133  0.431881
# 18 -91.637591  0.844894  1024.194899  89.382965  0.446946
# 19 -91.667613  0.822587   987.821456  89.363241  0.484046

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df[['nose_x', 'rShoulder_x', 'rElbow_x', 'rWrist_x',
       'lShoulder_x', 'lElbow_x', 'lWrist_x', 'rHip_x', 'rKnee_x', 'rAnkle_x',
       'lHip_x', 'lKnee_x', 'lAnkle_x', 'rEye_x', 'lEye_x', 'rEar_x', 'lEar_x',
       'nose_y', 'rShoulder_y', 'rElbow_y', 'rWrist_y',
       'lShoulder_y', 'lElbow_y', 'lWrist_y', 'rHip_y', 'rKnee_y', 'rAnkle_y',
       'lHip_y', 'lKnee_y', 'lAnkle_y', 'rEye_y', 'lEye_y', 'rEar_y', 'lEar_y',
       'rLowerLegLen', 'lLowerLegLen', 'lUpperLegLen', 'rUpperLegLen',
       'rBackLen', 'lBackLen', 'mBackLen', 'bodyLen']] =scaler.fit_transform(df[['nose_x', 'rShoulder_x', 'rElbow_x', 'rWrist_x',
       'lShoulder_x', 'lElbow_x', 'lWrist_x', 'rHip_x', 'rKnee_x', 'rAnkle_x',
       'lHip_x', 'lKnee_x', 'lAnkle_x', 'rEye_x', 'lEye_x', 'rEar_x', 'lEar_x',
       'nose_y', 'rShoulder_y', 'rElbow_y', 'rWrist_y',
       'lShoulder_y', 'lElbow_y', 'lWrist_y', 'rHip_y', 'rKnee_y', 'rAnkle_y',
       'lHip_y', 'lKnee_y', 'lAnkle_y', 'rEye_y', 'lEye_y', 'rEar_y', 'lEar_y',
       'rLowerLegLen', 'lLowerLegLen', 'lUpperLegLen', 'rUpperLegLen',
       'rBackLen', 'lBackLen', 'mBackLen', 'bodyLen']])

# %%
"""'rLowerHandLen', 'lLowerHandLen',
       'lUpperHandLen', 'rUpperHandLen',"""
# Out:
# "'rLowerHandLen', 'lLowerHandLen',\n       'lUpperHandLen', 'rUpperHandLen',"

# %%
 df["in"]=df.index

# %%
 for i in df.columns:
    if i[-1]=='s':
        df=df[df[i]>0.3]

# %%
df.count()
# Out:
# nose_x      383
# nose_y      383
# nose_s      383
# lEye_x      383
# lEye_y      383
#            ...
# mBackScr    383
# bodyLen     383
# bodyAng     383
# bodykScr    383
# in          383
# Length: 68, dtype: int64

# %%
plt.scatter(df["in"],df["nose_y"])

# %%
#SAVING REFRENCE DATA
ref_mm={}
for i in df.columns:
    if i[-1]=='g':
        ref_mm[i+'_max']=df[i].max()
        ref_mm[i+'_min']=df[i].min()
ref_mm
# Out:
# {'rLowerLegAng_max': 180.09129861342763,
#  'rLowerLegAng_min': -161.64699931680482,
#  'lLowerLegAng_max': 135.06876568211732,
#  'lLowerLegAng_min': -135.06847396007072,
#  'lUpperLegAng_max': -82.91699570107986,
#  'lUpperLegAng_min': -110.61213683561407,
#  'rUpperLegAng_max': -68.23317337413572,
#  'rUpperLegAng_min': -94.81168989866322,
#  'rBackAng_max': -87.03133064903996,
#  'rBackAng_min': -100.35571558787491,
#  'lBackAng_max': -77.94476200024795,
#  'lBackAng_min': -87.44177531732232,
#  'mBackAng_max': -81.98714937658318,
#  'mBackAng_min': -93.00808947609704,
#  'bodyAng_max': 90.0456468429037,
#  'bodyAng_min': -90.04564930671381}

# %%
min_a={}
max_a={}
min_l={}
for i in df.columns:
    if i[-1]=='g':
        min_a[i]=df[i].min()
        max_a[i]=df[i].max()
    if i[-1]=='n':
        min_l[i]=df[i].min()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

test=pd.read_csv('lunges.csv')
pd.set_option('display.max_columns', None)
print(len(test))
ind=len(test)
test['rLowerLegLen']=((test['rKnee_x']-test['rAnkle_x'])**2+(test['rKnee_y']-test['rAnkle_y'])**2)**.5
test['rLowerLegAng']=np.arctan2((test['rKnee_y']-test['rAnkle_y']),(test['rKnee_x']-test['rAnkle_x']))*180/3.14
test['rLowerLegScr']=(test['rKnee_s']*test['rAnkle_s'])**.5
test['lLowerLegLen']=((test['lKnee_x']-test['lAnkle_x'])**2+(test['lKnee_y']-test['lAnkle_y'])**2)**.5
test['lLowerLegAng']=np.arctan2((test['lKnee_y']-test['lAnkle_y']),(test['lKnee_x']-test['lAnkle_x']))*180/3.14
test['lLowerLegScr']=(test['lKnee_s']*test['lAnkle_s'])**.5
test['lUpperLegLen']=((test['lHip_x']-test['lKnee_x'])**2+(test['lHip_y']-test['lKnee_y'])**2)**.5
test['lUpperLegAng']=np.arctan2((test['lHip_y']-test['lKnee_y']),(test['lHip_x']-test['lKnee_x']))*180/3.14
test['lUpperLegScr']=(test['lKnee_s']*test['lHip_s'])**.5
test['rUpperLegLen']=((test['rHip_x']-test['rKnee_x'])**2+(test['rHip_y']-test['rKnee_y'])**2)**.5
test['rUpperLegAng']=np.arctan2((test['rHip_y']-test['rKnee_y']),(test['rHip_x']-test['rKnee_x']))*180/3.14
test['rUpperLegScr']=(test['rKnee_s']*test['rHip_s'])**.5

test['rBackLen']=((test['rHip_x']-test['rShoulder_x'])**2+(test['rHip_y']-test['rShoulder_y'])**2)**.5
test['rBackAng']=np.arctan2((test['rShoulder_y']-test['rHip_y']),(test['rShoulder_x']-test['rHip_x']))*180/3.14
test['rBackScr']=(test['rHip_s']*test['rShoulder_s'])**.5
test['lBackLen']=((test['lHip_x']-test['lShoulder_x'])**2+(test['lHip_y']-test['lShoulder_y'])**2)**.5
test['lBackAng']=np.arctan2((test['lShoulder_y']-test['lHip_y']),(test['lShoulder_x']-test['lHip_x']))*180/3.14
test['lBackScr']=(test['lHip_s']*test['lShoulder_s'])**.5
test['mBackLen']=((((test['rHip_x']+test['lHip_x'])/2)-test['nose_x'])**2+(((test['rHip_y']+test['lHip_y'])/2)-test['nose_y'])**2)**.5
test['mBackAng']=np.arctan2((test['nose_y']-((test['rHip_y']+test['lHip_y'])/2)),(test['nose_x']-((test['rHip_x']+test['lHip_x'])/2)))*180/3.14
test['mBackScr']=(((test['lHip_s']*test['lHip_s'])**.5)*test['nose_s'])**.5

test['bodyLen']=((((test['rAnkle_x']+test['lAnkle_x'])/2)-test['nose_x'])**2+(((test['rAnkle_y']+test['lAnkle_y'])/2)-test['nose_y'])**2)**.5
test['bodyAng']=np.arctan((test['nose_y']-((test['rAnkle_y']+test['lAnkle_y'])/2))/(test['nose_x']-((test['rAnkle_x']+test['lAnkle_x'])/2)))*180/3.14
test['bodykScr']=(((test['lAnkle_s']*test['lAnkle_s'])**.5)*test['nose_s'])**.5

test=test.drop(columns=['rElbow_s', 'rWrist_s', 'lElbow_s', 'lWrist_s', 'rEye_s', 'lEye_s', 'rEar_s', 'lEar_s'])
test.head()

#test.to_csv('Squats_m.csv')

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
test[['nose_x', 'rShoulder_x', 'rElbow_x', 'rWrist_x',
       'lShoulder_x', 'lElbow_x', 'lWrist_x', 'rHip_x', 'rKnee_x', 'rAnkle_x',
       'lHip_x', 'lKnee_x', 'lAnkle_x', 'rEye_x', 'lEye_x', 'rEar_x', 'lEar_x',
       'nose_y', 'rShoulder_y', 'rElbow_y', 'rWrist_y',
       'lShoulder_y', 'lElbow_y', 'lWrist_y', 'rHip_y', 'rKnee_y', 'rAnkle_y',
       'lHip_y', 'lKnee_y', 'lAnkle_y', 'rEye_y', 'lEye_y', 'rEar_y', 'lEar_y',
       'rLowerLegLen', 'lLowerLegLen', 'lUpperLegLen', 'rUpperLegLen',
       'rBackLen', 'lBackLen', 'mBackLen', 'bodyLen']] =scaler.fit_transform(test[['nose_x', 'rShoulder_x', 'rElbow_x', 'rWrist_x',
       'lShoulder_x', 'lElbow_x', 'lWrist_x', 'rHip_x', 'rKnee_x', 'rAnkle_x',
       'lHip_x', 'lKnee_x', 'lAnkle_x', 'rEye_x', 'lEye_x', 'rEar_x', 'lEar_x',
       'nose_y', 'rShoulder_y', 'rElbow_y', 'rWrist_y',
       'lShoulder_y', 'lElbow_y', 'lWrist_y', 'rHip_y', 'rKnee_y', 'rAnkle_y',
       'lHip_y', 'lKnee_y', 'lAnkle_y', 'rEye_y', 'lEye_y', 'rEar_y', 'lEar_y',
       'rLowerLegLen', 'lLowerLegLen', 'lUpperLegLen', 'rUpperLegLen',
       'rBackLen', 'lBackLen', 'mBackLen', 'bodyLen']])

"""'rLowerHandLen', 'lLowerHandLen',
       'lUpperHandLen', 'rUpperHandLen',"""

test["in"]=test.index

for i in test.columns:
    if i[-1]=='s':
        test=test[test[i]>0.35]

len(test)
# Out:
# 487
# 348

# %%
#SAVING EVERY RESOLUTIONS MIN AND MAX FOR COMPARISON
from scipy.signal import argrelextrema
min_max={}
n=20
for i in test.columns:
    if i[-1]!='x':
        test['min'] = test.iloc[argrelextrema(test[i].values, np.less_equal, order=n)[0]][i]
        test['max'] = test.iloc[argrelextrema(test[i].values, np.greater_equal, order=n)[0]][i]
        # Plot results
        plt.scatter(test.index, test['min'], c='r')
        plt.scatter(test.index, test['max'], c='g')
        #x=test['min'].values
        #min_max[i+'_min']=x[np.logical_not(np.isnan(x))]
        #y=test['max'].values
        #min_max[i+'_max']=y[np.logical_not(np.isnan(y))]
        plt.plot(test.index, test[i])
        print(i)
        print('Min',test['min'].count())
        print('Max:',test['max'].count())
        min_max[i+'_min']=test[['min']]
        min_max[i+'_max']=test[['max']]
        min_max[i+'_min']=min_max[i+'_min'].dropna()
        min_max[i+'_max']=min_max[i+'_max'].dropna()
        min_max[i+'_min'].columns = ['m']
        min_max[i+'_max'].columns = ['m']
        plt.show()
# Out:
# nose_y
# Min 6
# Max: 6
# nose_s
# Min 9
# Max: 7
# lEye_y
# Min 6
# Max: 6
# rEye_y
# Min 6
# Max: 6
# lEar_y
# Min 6
# Max: 6
# rEar_y
# Min 6
# Max: 6
# lShoulder_y
# Min 6
# Max: 6
# lShoulder_s
# Min 9
# Max: 10
# rShoulder_y
# Min 6
# Max: 6
# rShoulder_s
# Min 7
# Max: 10
# lElbow_y
# Min 8
# Max: 6
# rElbow_y
# Min 6
# Max: 6
# lWrist_y
# Min 7
# Max: 6
# rWrist_y
# Min 8
# Max: 6
# lHip_y
# Min 6
# Max: 6
# lHip_s
# Min 6
# Max: 8
# rHip_y
# Min 6
# Max: 6
# rHip_s
# Min 6
# Max: 8
# lKnee_y
# Min 6
# Max: 7
# lKnee_s
# Min 6
# Max: 8
# rKnee_y
# Min 6
# Max: 6
# rKnee_s
# Min 9
# Max: 9
# lAnkle_y
# Min 4
# Max: 6
# lAnkle_s
# Min 7
# Max: 9
# rAnkle_y
# Min 10
# Max: 5
# rAnkle_s
# Min 6
# Max: 9
# rLowerLegLen
# Min 6
# Max: 4
# rLowerLegAng
# Min 5
# Max: 10
# rLowerLegScr
# Min 8
# Max: 8
# lLowerLegLen
# Min 9
# Max: 5
# lLowerLegAng
# Min 24
# Max: 7
# lLowerLegScr
# Min 6
# Max: 9
# lUpperLegLen
# Min 6
# Max: 5
# lUpperLegAng
# Min 10
# Max: 10
# lUpperLegScr
# Min 6
# Max: 9
# rUpperLegLen
# Min 5
# Max: 7
# rUpperLegAng
# Min 18
# Max: 6
# rUpperLegScr
# Min 7
# Max: 9
# rBackLen
# Min 7
# Max: 7
# rBackAng
# Min 8
# Max: 12
# rBackScr
# Min 7
# Max: 9
# lBackLen
# Min 8
# Max: 6
# lBackAng
# Min 8
# Max: 7
# lBackScr
# Min 8
# Max: 8
# mBackLen
# Min 8
# Max: 6
# mBackAng
# Min 7
# Max: 7
# mBackScr
# Min 7
# Max: 7
# bodyLen
# Min 8
# Max: 8
# bodyAng
# Min 8
# Max: 8
# bodykScr
# Min 7
# Max: 10
# in
# Min 1
# Max: 1

# %%
er=pd.DataFrame(index=np.arange(ind), columns=['error'])
er=er.fillna(0)

# %%
ref_mm={}
for i in test.columns:
    if (i[-1]=='x') or (i[-1]=='y') or (i[-1]=='s') or (i[-1]=='g') or (i[-1]=='r') or (i[-1]=='n') :
        ref_mm[i+'_max']=test[i].max()
        ref_mm[i+'_min']=test[i].min()
ref_mm
# Out:
# {'nose_x_max': 1.0,
#  'nose_x_min': 0.014284787797230969,
#  'nose_y_max': 0.9111248368785165,
#  'nose_y_min': 0.0,
#  'nose_s_max': 0.9578397870063782,
#  'nose_s_min': 0.7470669150352478,
#  'lEye_x_max': 1.0,
#  'lEye_x_min': 0.013450967674305758,
#  'lEye_y_max': 0.9237445529014253,
#  'lEye_y_min': 0.0,
#  'rEye_x_max': 1.0,
#  'rEye_x_min': 0.0,
#  'rEye_y_max': 0.9087397610998592,
#  'rEye_y_min': 0.0,
#  'lEar_x_max': 1.0,
#  'lEar_x_min': 0.00440029035775602,
#  'lEar_y_max': 0.9100472569895628,
#  'lEar_y_min': 0.0,
#  'rEar_x_max': 1.0000000000000002,
#  'rEar_x_min': 0.0,
#  'rEar_y_max': 0.9094277014603145,
#  'rEar_y_min': 0.0,
#  'lShoulder_x_max': 1.0000000000000004,
#  'lShoulder_x_min': 0.04859133944049976,
#  'lShoulder_y_max': 0.9069352733284721,
#  'lShoulder_y_min': 0.0,
#  'lShoulder_s_max': 0.9093038439750672,
#  'lShoulder_s_min': 0.7543608546257019,
#  'rShoulder_x_max': 0.9893646417586262,
#  'rShoulder_x_min': 0.0,
#  'rShoulder_y_max': 0.9003556535735557,
#  'rShoulder_y_min': 0.0,
#  'rShoulder_s_max': 0.9254226088523864,
#  'rShoulder_s_min': 0.7623877525329591,
#  'lElbow_x_max': 0.8931292645634463,
#  'lElbow_x_min': 0.36826667600701346,
#  'lElbow_y_max': 0.930812274325554,
#  'lElbow_y_min': 0.16625655373449527,
#  'rElbow_x_max': 0.5581657443859009,
#  'rElbow_x_min': 0.0,
#  'rElbow_y_max': 0.9364311417717794,
#  'rElbow_y_min': 0.17123748284058288,
#  'lWrist_x_max': 0.884569799666639,
#  'lWrist_x_min': 0.39338998839479455,
#  'lWrist_y_max': 0.9517718033214795,
#  'lWrist_y_min': 0.19936196486464855,
#  'rWrist_x_max': 0.52340794273336,
#  'rWrist_x_min': 0.0,
#  'rWrist_y_max': 0.9659552681423408,
#  'rWrist_y_min': 0.2009886382047078,
#  'lHip_x_max': 1.0,
#  'lHip_x_min': 0.010901132288011262,
#  'lHip_y_max': 0.9334672168585967,
#  'lHip_y_min': 0.40503301584627505,
#  'lHip_s_max': 0.8544189333915709,
#  'lHip_s_min': 0.5963796973228455,
#  'rHip_x_max': 0.4870363763457317,
#  'rHip_x_min': 0.01688221422740155,
#  'rHip_y_max': 0.9232951766875652,
#  'rHip_y_min': 0.3940066095648832,
#  'rHip_s_max': 0.8393623828887941,
#  'rHip_s_min': 0.6261231303215027,
#  'lKnee_x_max': 1.0,
#  'lKnee_x_min': 0.36424865394028405,
#  'lKnee_y_max': 0.95018964375914,
#  'lKnee_y_min': 0.5181589714703467,
#  'lKnee_s_max': 0.9561054110527042,
#  'lKnee_s_min': 0.5538691878318787,
#  'rKnee_x_max': 0.5966221155794231,
#  'rKnee_x_min': 0.02435886696044276,
#  'rKnee_y_max': 0.9363781613861148,
#  'rKnee_y_min': 0.507684528831688,
#  'rKnee_s_max': 0.9604594111442566,
#  'rKnee_s_min': 0.5054048299789429,
#  'lAnkle_x_max': 1.0,
#  'lAnkle_x_min': 0.16830402766146113,
#  'lAnkle_y_max': 0.9999737761029905,
#  'lAnkle_y_min': 0.54440927994147,
#  'lAnkle_s_max': 0.8909802436828613,
#  'lAnkle_s_min': 0.3640708625316621,
#  'rAnkle_x_max': 0.4688010819704531,
#  'rAnkle_x_min': 0.0,
#  'rAnkle_y_max': 0.9999999999999999,
#  'rAnkle_y_min': 0.5658547432631181,
#  'rAnkle_s_max': 0.9077695608139038,
#  'rAnkle_s_min': 0.41039395332336426,
#  'rLowerLegLen_max': 1.0,
#  'rLowerLegLen_min': 0.02873296766505423,
#  'rLowerLegAng_max': 180.09129861342763,
#  'rLowerLegAng_min': -161.64699931680482,
#  'rLowerLegScr_max': 0.9009003991039725,
#  'rLowerLegScr_min': 0.5535053029205429,
#  'lLowerLegLen_max': 1.0,
#  'lLowerLegLen_min': 0.006901295964970522,
#  'lLowerLegAng_max': 135.06876568211732,
#  'lLowerLegAng_min': -135.06847396007072,
#  'lLowerLegScr_max': 0.8920675914135867,
#  'lLowerLegScr_min': 0.4941920826022565,
#  'lUpperLegLen_max': 1.0,
#  'lUpperLegLen_min': 0.4376904685813894,
#  'lUpperLegAng_max': -82.91699570107986,
#  'lUpperLegAng_min': -110.61213683561407,
#  'lUpperLegScr_max': 0.8603515574873855,
#  'lUpperLegScr_min': 0.6315096075993599,
#  'rUpperLegLen_max': 1.0,
#  'rUpperLegLen_min': 0.472592841785368,
#  'rUpperLegAng_max': -71.60134549254529,
#  'rUpperLegAng_min': -94.81168989866322,
#  'rUpperLegScr_max': 0.8584234981277811,
#  'rUpperLegScr_min': 0.6283993420441094,
#  'rBackLen_max': 1.0,
#  'rBackLen_min': 0.6206754855440402,
#  'rBackAng_max': -87.03133064903996,
#  'rBackAng_min': -99.51276868927438,
#  'rBackScr_max': 0.8542022818678336,
#  'rBackScr_min': 0.7050532058485963,
#  'lBackLen_max': 1.0,
#  'lBackLen_min': 0.7011022772165171,
#  'lBackAng_max': -77.94476200024795,
#  'lBackAng_min': -87.44177531732232,
#  'lBackScr_max': 0.8609957490422702,
#  'lBackScr_min': 0.6970085255476963,
#  'mBackLen_max': 1.0,
#  'mBackLen_min': 0.6941013435329113,
#  'mBackAng_max': -81.98714937658318,
#  'mBackAng_min': -93.00808947609704,
#  'mBackScr_max': 0.8958923381589768,
#  'mBackScr_min': 0.6938273122582232,
#  'bodyLen_max': 0.9999999999999999,
#  'bodyLen_min': 0.6853773924935418,
#  'bodyAng_max': 90.0456468429037,
#  'bodyAng_min': -90.04564930671381,
#  'bodykScr_max': 0.9092848518663297,
#  'bodykScr_min': 0.5599965027210005,
#  'in_max': 486,
#  'in_min': 0,
#  'min_max': 0.0,
#  'min_min': 0.0,
#  'max_max': 486.0,
#  'max_min': 486.0}

# %%
min_max
# Out:
# {'nose_y_min':             m
#  61   0.000000
#  168  0.251389
#  222  0.270253
#  313  0.298011
#  395  0.319765
#  484  0.328860,
#  'nose_y_max':             m
#  16   0.519404
#  98   0.466154
#  198  0.896074
#  262  0.640196
#  354  0.911125
#  428  0.646008,
#  'nose_s_min':             m
#  60   0.747067
#  148  0.850671
#  204  0.861360
#  242  0.829216
#  291  0.877122
#  371  0.853965
#  412  0.836182
#  460  0.880084
#  486  0.878742,
#  'nose_s_max':             m
#  54   0.953844
#  141  0.950866
#  175  0.944646
#  259  0.945307
#  337  0.937453
#  383  0.947246
#  465  0.957840,
#  'lEye_y_min':             m
#  61   0.000000
#  167  0.233245
#  221  0.248514
#  313  0.290151
#  395  0.298549
#  483  0.321262,
#  'lEye_y_max':             m
#  16   0.495133
#  98   0.459734
#  198  0.893173
#  262  0.640368
#  354  0.923745
#  428  0.645681,
#  'rEye_y_min':             m
#  61   0.000000
#  167  0.233245
#  221  0.248514
#  307  0.285358
#  395  0.298549
#  483  0.321262,
#  'rEye_y_max':             m
#  16   0.495133
#  98   0.459734
#  198  0.893173
#  262  0.640368
#  354  0.908740
#  428  0.645681,
#  'lEar_y_min':             m
#  64   0.000000
#  167  0.250022
#  221  0.265383
#  310  0.295719
#  395  0.316172
#  484  0.325536,
#  'lEar_y_max':             m
#  16   0.503844
#  98   0.466884
#  198  0.894548
#  262  0.662698
#  354  0.910047
#  428  0.652050,
#  'rEar_y_min':             m
#  63   0.000000
#  166  0.259245
#  222  0.278556
#  313  0.307177
#  395  0.314956
#  484  0.338986,
#  'rEar_y_max':             m
#  16   0.517569
#  98   0.480552
#  198  0.893900
#  262  0.660010
#  354  0.909428
#  428  0.666003,
#  'lShoulder_y_min':             m
#  59   0.000000
#  167  0.275189
#  221  0.290785
#  313  0.313792
#  395  0.344798
#  484  0.345520,
#  'lShoulder_y_max':             m
#  16   0.561028
#  98   0.496050
#  198  0.892091
#  262  0.662907
#  354  0.906935
#  428  0.673649,
#  'lShoulder_s_min':             m
#  48   0.763419
#  72   0.754361
#  152  0.783063
#  221  0.774159
#  288  0.769927
#  312  0.803896
#  352  0.790685
#  391  0.770480
#  456  0.802353,
#  'lShoulder_s_max':             m
#  5    0.859754
#  87   0.884182
#  140  0.892561
#  180  0.865184
#  227  0.864483
#  249  0.875515
#  296  0.882686
#  331  0.877165
#  378  0.891415
#  471  0.909304,
#  'rShoulder_y_min':             m
#  63   0.000000
#  167  0.268783
#  222  0.284392
#  314  0.299348
#  395  0.325297
#  485  0.341585,
#  'rShoulder_y_max':             m
#  16   0.593163
#  98   0.475495
#  198  0.899876
#  285  0.675335
#  354  0.900356
#  428  0.674174,
#  'rShoulder_s_min':             m
#  12   0.777385
#  69   0.780037
#  140  0.762388
#  208  0.772338
#  293  0.765770
#  375  0.782150
#  456  0.784458,
#  'rShoulder_s_max':             m
#  0    0.885927
#  87   0.896837
#  144  0.895844
#  176  0.920758
#  239  0.883585
#  302  0.875274
#  337  0.925423
#  383  0.918840
#  426  0.882593
#  475  0.882928,
#  'lElbow_y_min':             m
#  0    0.485458
#  59   0.166257
#  164  0.352720
#  222  0.371266
#  248  0.372067
#  316  0.372952
#  414  0.429046
#  486  0.408834,
#  'lElbow_y_max':             m
#  16   0.659266
#  124  0.536485
#  198  0.930812
#  285  0.702853
#  354  0.919947
#  455  0.678401,
#  'rElbow_y_min':             m
#  60   0.171237
#  152  0.401029
#  220  0.390204
#  320  0.417416
#  394  0.425618
#  486  0.428679,
#  'rElbow_y_max':             m
#  16   0.664441
#  98   0.538883
#  198  0.936431
#  285  0.766861
#  354  0.924891
#  428  0.712869,
#  'lWrist_y_min':             m
#  0    0.473486
#  59   0.199362
#  167  0.349627
#  245  0.343821
#  325  0.362602
#  415  0.411805
#  486  0.397507,
#  'lWrist_y_max':             m
#  16   0.700002
#  124  0.520894
#  198  0.951772
#  285  0.724031
#  354  0.909928
#  455  0.654510,
#  'rWrist_y_min':             m
#  0    0.471144
#  64   0.200989
#  154  0.410000
#  220  0.393935
#  249  0.389677
#  323  0.402062
#  413  0.432427
#  486  0.431231,
#  'rWrist_y_max':             m
#  16   0.668235
#  124  0.521617
#  198  0.965955
#  285  0.759789
#  354  0.922279
#  455  0.686737,
#  'lHip_y_min':             m
#  62   0.405033
#  163  0.570585
#  221  0.572753
#  314  0.583070
#  395  0.603038
#  484  0.611981,
#  'lHip_y_max':             m
#  15   0.800682
#  98   0.697032
#  198  0.916759
#  285  0.823716
#  354  0.933467
#  455  0.836465,
#  'lHip_s_min':             m
#  55   0.596380
#  221  0.662748
#  311  0.690671
#  333  0.723198
#  388  0.673437
#  455  0.709056,
#  'lHip_s_max':             m
#  14   0.772725
#  96   0.815729
#  183  0.854419
#  255  0.827195
#  302  0.821348
#  324  0.794838
#  345  0.813838
#  471  0.815254,
#  'rHip_y_min':             m
#  62   0.394007
#  161  0.563717
#  221  0.563986
#  314  0.574068
#  395  0.586455
#  485  0.613868,
#  'rHip_y_max':             m
#  15   0.804665
#  98   0.698891
#  198  0.906240
#  285  0.818677
#  354  0.923295
#  455  0.831332,
#  'rHip_s_min':             m
#  55   0.626123
#  158  0.722648
#  220  0.641100
#  310  0.707445
#  395  0.693314
#  469  0.719976,
#  'rHip_s_max':             m
#  43   0.784182
#  132  0.836317
#  172  0.797237
#  286  0.839362
#  337  0.788463
#  383  0.784439
#  421  0.830462
#  473  0.838094,
#  'lKnee_y_min':             m
#  63   0.518159
#  155  0.649374
#  228  0.651209
#  313  0.660905
#  406  0.682407
#  486  0.697706,
#  'lKnee_y_max':             m
#  15   0.807073
#  16   0.807073
#  98   0.777428
#  198  0.950099
#  285  0.887686
#  354  0.950190
#  455  0.937351,
#  'lKnee_s_min':             m
#  15   0.553869
#  124  0.810584
#  209  0.625989
#  261  0.808160
#  344  0.570734
#  468  0.825049,
#  'lKnee_s_max':             m
#  43   0.956105
#  92   0.945050
#  198  0.945078
#  250  0.913355
#  301  0.909275
#  353  0.877812
#  411  0.887473
#  463  0.914548,
#  'rKnee_y_min':             m
#  62   0.507685
#  153  0.628860
#  229  0.644694
#  314  0.646745
#  403  0.675638
#  486  0.689325,
#  'rKnee_y_max':             m
#  15   0.881459
#  98   0.738206
#  198  0.915658
#  262  0.838710
#  354  0.936378
#  428  0.876798,
#  'rKnee_s_min':             m
#  2    0.796857
#  48   0.774418
#  127  0.610586
#  175  0.796552
#  218  0.822083
#  287  0.505405
#  338  0.806251
#  385  0.800094
#  456  0.683551,
#  'rKnee_s_max':             m
#  42   0.893713
#  160  0.938287
#  183  0.916824
#  227  0.929233
#  262  0.960459
#  309  0.935728
#  391  0.889265
#  413  0.874978
#  478  0.903603,
#  'lAnkle_y_min':             m
#  52   0.544409
#  185  0.652878
#  314  0.678313
#  483  0.713421,
#  'lAnkle_y_max':             m
#  2    0.731955
#  134  0.851786
#  198  0.777390
#  261  0.943476
#  354  0.759900
#  455  0.999974,
#  'lAnkle_s_min':             m
#  14   0.390290
#  79   0.767086
#  131  0.784314
#  204  0.364071
#  258  0.760592
#  354  0.368322
#  463  0.749897,
#  'lAnkle_s_max':             m
#  2    0.871903
#  83   0.886924
#  155  0.869647
#  215  0.879111
#  242  0.877050
#  327  0.890980
#  380  0.876214
#  412  0.866342
#  484  0.866255,
#  'rAnkle_y_min':             m
#  61   0.565855
#  126  0.608834
#  164  0.646245
#  222  0.675326
#  290  0.674380
#  291  0.674380
#  292  0.674380
#  293  0.674380
#  392  0.715233
#  475  0.729375,
#  'rAnkle_y_max':             m
#  7    1.000000
#  199  0.936741
#  261  0.712133
#  352  0.960323
#  428  0.762737,
#  'rAnkle_s_min':             m
#  48   0.738874
#  124  0.484707
#  215  0.764089
#  262  0.410394
#  378  0.757864
#  455  0.547748,
#  'rAnkle_s_max':             m
#  81   0.875636
#  132  0.907770
#  155  0.877719
#  183  0.858705
#  233  0.890879
#  295  0.878886
#  322  0.886114
#  424  0.899411
#  482  0.867188,
#  'rLowerLegLen_min':             m
#  126  0.028733
#  221  0.392446
#  285  0.080114
#  326  0.405680
#  392  0.415690
#  455  0.065711,
#  'rLowerLegLen_max':             m
#  0    1.000000
#  212  0.906446
#  377  0.936925
#  486  0.535483,
#  'rLowerLegAng_min':               m
#  95  -153.512714
#  291 -135.068523
#  328 -102.580828
#  390 -100.835420
#  426 -161.646999,
#  'rLowerLegAng_max':               m
#  1    -82.917012
#  48   -78.063432
#  96   180.091299
#  97   180.091299
#  176  -84.136522
#  213  -86.098462
#  259  168.775512
#  379  -80.258277
#  428  166.048080
#  486  -92.773343,
#  'rLowerLegScr_min':             m
#  48   0.756438
#  69   0.787605
#  124  0.594317
#  215  0.794326
#  285  0.553505
#  335  0.796675
#  385  0.785785
#  455  0.626305,
#  'rLowerLegScr_max':             m
#  40   0.852548
#  81   0.854837
#  160  0.900900
#  183  0.887289
#  233  0.898546
#  309  0.895760
#  389  0.856930
#  478  0.878341,
#  'lLowerLegLen_min':             m
#  45   0.017113
#  78   0.379714
#  148  0.373685
#  183  0.006901
#  242  0.420353
#  306  0.387184
#  370  0.042180
#  410  0.376393
#  483  0.449930,
#  'lLowerLegLen_max':             m
#  0    0.359074
#  1    0.359074
#  134  0.930903
#  293  1.000000
#  469  0.997894,
#  'lLowerLegAng_min':               m
#  14  -135.068474
#  67   -90.045649
#  69   -90.045649
#  70   -90.045649
#  71   -90.045649
#  76   -90.045649
#  77   -90.045649
#  78   -90.045649
#  87   -90.045649
#  88   -90.045649
#  89   -90.045649
#  139  -92.092096
#  209  -90.045649
#  250  -90.045649
#  251  -90.045649
#  252  -90.045649
#  253  -90.045649
#  254  -90.045649
#  295  -90.045649
#  296  -90.045649
#  297  -90.045649
#  372 -104.089012
#  419  -92.092105
#  470  -91.731184,
#  'lLowerLegAng_max':               m
#  15   135.068766
#  83   -77.234883
#  145  -70.856919
#  198   99.512790
#  303  -71.601339
#  354   96.389074
#  480  -78.150958,
#  'lLowerLegScr_min':             m
#  16   0.494192
#  132  0.823868
#  204  0.556194
#  258  0.793572
#  345  0.536672
#  404  0.811189,
#  'lLowerLegScr_max':             m
#  8    0.857796
#  54   0.861358
#  92   0.892068
#  155  0.880711
#  242  0.889948
#  301  0.875639
#  333  0.865246
#  411  0.870001
#  484  0.861127,
#  'lUpperLegLen_min':             m
#  2    0.456764
#  151  0.570737
#  179  0.482153
#  218  0.544205
#  379  0.437690
#  486  0.650051,
#  'lUpperLegLen_max':             m
#  132  0.894266
#  202  0.722603
#  294  0.920961
#  345  0.652658
#  461  1.000000,
#  'lUpperLegAng_min':               m
#  8   -110.612137
#  11  -110.612137
#  82   -96.389047
#  144  -97.480823
#  207  -97.814745
#  245  -97.174283
#  301  -99.916457
#  353  -99.916460
#  427  -98.796257
#  479  -96.164259,
#  'lUpperLegAng_max':               m
#  0   -100.058709
#  56   -88.069720
#  92   -90.045649
#  98   -90.045649
#  172  -84.848587
#  225  -85.279586
#  326  -82.917006
#  397  -82.916996
#  463  -91.955755
#  486  -90.045649,
#  'lUpperLegScr_min':             m
#  15   0.631510
#  209  0.672790
#  310  0.759576
#  344  0.653722
#  455  0.781576
#  485  0.785738,
#  'lUpperLegScr_max':             m
#  43   0.846107
#  90   0.858841
#  146  0.847265
#  205  0.816624
#  255  0.856697
#  302  0.860352
#  324  0.824781
#  352  0.835865
#  465  0.845732,
#  'rUpperLegLen_min':             m
#  44   0.683722
#  132  0.522915
#  229  0.642451
#  289  0.472593
#  459  0.575090,
#  'rUpperLegLen_max':             m
#  5    1.000000
#  7    1.000000
#  179  0.905063
#  260  0.775557
#  376  0.959707
#  428  0.814844
#  479  0.777351,
#  'rUpperLegAng_min':              m
#  11  -80.258280
#  76  -92.021579
#  150 -87.841927
#  249 -94.811690
#  309 -90.045649
#  310 -90.045649
#  419 -92.773357
#  476 -90.045649
#  477 -90.045649
#  478 -90.045649
#  479 -90.045649
#  480 -90.045649
#  481 -90.045649
#  482 -90.045649
#  483 -90.045649
#  484 -90.045649
#  485 -90.045649
#  486 -90.045649,
#  'rUpperLegAng_max':              m
#  44  -71.601345
#  96  -80.578533
#  198 -76.002280
#  286 -75.106661
#  344 -74.395479
#  463 -75.294607,
#  'rUpperLegScr_min':             m
#  55   0.725480
#  127  0.699156
#  223  0.747535
#  288  0.628399
#  333  0.780319
#  394  0.763579
#  456  0.737555,
#  'rUpperLegScr_max':             m
#  14   0.834820
#  139  0.853481
#  160  0.848471
#  183  0.847099
#  235  0.852350
#  262  0.858423
#  345  0.834330
#  392  0.830528
#  465  0.845665,
#  'rBackLen_min':             m
#  71   0.620675
#  140  0.676642
#  199  0.689969
#  230  0.716874
#  310  0.719653
#  395  0.718169
#  479  0.740778,
#  'rBackLen_max':             m
#  8    1.000000
#  10   1.000000
#  126  0.849027
#  183  0.846253
#  288  0.864426
#  379  0.885348
#  460  0.984025,
#  'rBackAng_min':              m
#  12  -99.512769
#  13  -99.512769
#  124 -93.141286
#  199 -97.545311
#  285 -97.355111
#  342 -94.561936
#  415 -94.133342
#  479 -94.336980,
#  'rBackAng_max':              m
#  56  -91.215378
#  139 -88.408251
#  222 -90.045649
#  223 -90.045649
#  257 -90.045649
#  258 -90.045649
#  259 -90.045649
#  260 -90.045649
#  261 -90.045649
#  330 -87.251534
#  386 -87.031331
#  468 -88.496704,
#  'rBackScr_min':             m
#  55   0.705053
#  125  0.780342
#  158  0.774015
#  220  0.732057
#  310  0.766727
#  375  0.755263
#  469  0.759992,
#  'rBackScr_max':             m
#  0    0.829454
#  88   0.844298
#  143  0.846126
#  176  0.841039
#  286  0.836527
#  337  0.854202
#  383  0.848984
#  426  0.843951
#  474  0.849978,
#  'lBackLen_min':             m
#  40   0.768589
#  71   0.701102
#  142  0.739272
#  199  0.750192
#  231  0.741553
#  314  0.746113
#  406  0.751520
#  478  0.753226,
#  'lBackLen_max':             m
#  10   1.000000
#  131  0.852627
#  181  0.884050
#  289  0.886614
#  372  0.894736
#  459  0.942330,
#  'lBackAng_min':              m
#  10  -87.441775
#  81  -85.073394
#  145 -82.736180
#  184 -85.754318
#  244 -86.052718
#  341 -85.529378
#  414 -84.332165
#  484 -84.470631,
#  'lBackAng_max':              m
#  41  -78.729978
#  71  -79.501120
#  138 -78.729969
#  169 -80.351955
#  230 -79.864986
#  392 -77.944762
#  457 -79.864971,
#  'lBackScr_min':             m
#  55   0.697009
#  153  0.755060
#  221  0.716290
#  246  0.755012
#  311  0.751263
#  391  0.736394
#  455  0.763408
#  485  0.789800,
#  'lBackScr_max':             m
#  3    0.791527
#  87   0.833571
#  142  0.835454
#  183  0.856047
#  252  0.839545
#  296  0.838046
#  345  0.826648
#  471  0.860996,
#  'mBackLen_min':             m
#  71   0.694101
#  143  0.727655
#  199  0.720644
#  232  0.732070
#  314  0.740196
#  354  0.738118
#  395  0.750368
#  479  0.756505,
#  'mBackLen_max':             m
#  10   1.000000
#  125  0.837181
#  181  0.843058
#  288  0.882621
#  372  0.873004
#  461  0.930336,
#  'mBackAng_min':              m
#  14  -93.008089
#  81  -87.735420
#  184 -90.045653
#  285 -89.031154
#  343 -88.468301
#  410 -87.133335
#  484 -87.554836,
#  'mBackAng_max':              m
#  57  -85.419159
#  139 -84.033596
#  219 -84.671935
#  258 -84.848589
#  319 -83.479615
#  388 -81.987149
#  467 -83.643446,
#  'mBackScr_min':             m
#  60   0.693827
#  148  0.792795
#  221  0.768130
#  242  0.769202
#  310  0.788191
#  393  0.765759
#  485  0.805717,
#  'mBackScr_max':             m
#  46   0.845398
#  141  0.872970
#  183  0.895892
#  299  0.874285
#  324  0.853906
#  345  0.854409
#  465  0.883139,
#  'bodyLen_min':             m
#  40   0.741367
#  80   0.758080
#  147  0.737803
#  198  0.689473
#  233  0.780095
#  305  0.779369
#  354  0.685377
#  483  0.818510,
#  'bodyLen_max':             m
#  7    1.000000
#  131  0.852540
#  177  0.879958
#  213  0.873519
#  293  0.877450
#  376  0.902287
#  461  0.955115
#  462  0.955115,
#  'bodyAng_min':              m
#  5   -89.489117
#  85  -89.514879
#  138 -89.718083
#  184 -89.725404
#  250 -90.045649
#  354 -88.720454
#  417 -89.460722
#  482 -88.654543,
#  'bodyAng_max':              m
#  7    89.773969
#  126 -85.889689
#  161 -85.348353
#  199  89.379110
#  254  90.045647
#  333 -83.539293
#  382 -82.427077
#  455 -84.848587,
#  'bodykScr_min':             m
#  14   0.571181
#  148  0.831133
#  204  0.559997
#  291  0.831147
#  320  0.844298
#  352  0.570286
#  463  0.821496,
#  'bodykScr_max':             m
#  8    0.882396
#  54   0.892234
#  83   0.905638
#  141  0.896963
#  175  0.903143
#  215  0.906261
#  312  0.909285
#  385  0.895095
#  419  0.890729
#  484  0.884643,
#  'in_min':      m
#  0  0.0,
#  'in_max':          m
#  486  486.0}

# %%
for i in min_max:
    for index in min_max[i].index:
        if min_max[i]['m'][index]<ref_mm[i]-10 or min_max[i]['m'][index]>ref_mm[i]+10:
            er['error'][index]=er['error'][index]+1

# %%
er['error'].value_counts()
# Out:
# 0    432
# 1     55
# Name: error, dtype: int64

# %%
gr=er[er['error']>2].index
gr
# Out:
# Int64Index([], dtype='int64')

# %%
from scipy.signal import argrelextrema
n=40
df['counts'] = df.iloc[argrelextrema(df.nose_y.values, np.greater_equal, order=n)[0]]['nose_y']
plt.scatter(df.index, df['counts'], c='b')
plt.plot(df.index, df['nose_y'])
plt.show()
b = df['counts'].count()
print('Count of reps:',b)
# Out:
# Count of reps: 6

# %%
import os
import cv2
def FrameCapture(path): 
      
    # Path to video file 
    vidObj = cv2.VideoCapture(path) 
    font = cv2.FONT_HERSHEY_SIMPLEX 
    # Used as counter variable 
    count = 0
    c=0
    # checks whether frames were extracted 
    success = 1
    #success, image = vidObj.read()
    while success: 
        # vidObj object calls read 
        # function extract frames 
        success, image = vidObj.read()
        if count in gr:
            c=c+10
        # Saves the frames with frame-count 
        if c>0:
            image = cv2.putText(image,'WRONG',(50, 50),font, 1,  
                (255, 0, 0),4, cv2.LINE_4)
#             image=cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
            c=c-1
        image1 = cv2.putText(image,'Count of reps:'+str(b),(50, 50),font, 1,  
                (255, 0, 0),4, cv2.LINE_4)
        cv2.imwrite("frame%d.jpg" % count, image1) 
        count += 1

FrameCapture("D:\Prith\Lunges\Attempt1\lun1.mp4")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-27-bfc81c2519e3> in <module>
#      29         count += 1
#      30
# ---> 31 FrameCapture("D:\Prith\Lunges\Attempt1\lun1.mp4")
#
# <ipython-input-27-bfc81c2519e3> in FrameCapture(path)
#      26         image1 = cv2.putText(image,'Count of reps:'+str(b),(50, 50),font, 1,
#      27                 (255, 0, 0),4, cv2.LINE_4)
# ---> 28         cv2.imwrite("frame%d.jpg" % count, image1)
#      29         count += 1
#      30
#
# error: OpenCV(4.4.0) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-6sxsq0tp\opencv\modules\imgcodecs\src\loadsave.cpp:738: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'

# %%
# Video Generating function 
def generate_video(): 
    image_folder = '.' # make sure to use your folder 
    video_name = 'test.mp4'
      
    images = [img for img in os.listdir(image_folder) 
              if img.endswith(".jpg") or
                 img.endswith(".jpeg") or
                 img.endswith("png")] 
     
    # Array images should only consider 
    # the image files ignoring others if any 
    print(images)  
  
    frame = cv2.imread(os.path.join(image_folder, images[0])) 
  
    # setting the frame width, height width 
    # the width, height of first image 
    height, width, layers = frame.shape   
  
    video = cv2.VideoWriter(video_name, 0, 60, (width, height))  
  
    # Appending the images to the video one by one 
    for image in images:  
        video.write(cv2.imread(os.path.join(image_folder, image)))  
      
    # Deallocating memories taken for window creation 
    cv2.destroyAllWindows()  
    video.release()  # releasing the video generated 
  
  
# Calling the generate_video function 
generate_video()
# Out:
# ['frame0.jpg', 'frame1.jpg', 'frame10.jpg', 'frame100.jpg', 'frame101.jpg', 'frame102.jpg', 'frame103.jpg', 'frame104.jpg', 'frame105.jpg', 'frame106.jpg', 'frame107.jpg', 'frame108.jpg', 'frame109.jpg', 'frame11.jpg', 'frame110.jpg', 'frame111.jpg', 'frame112.jpg', 'frame113.jpg', 'frame114.jpg', 'frame115.jpg', 'frame116.jpg', 'frame117.jpg', 'frame118.jpg', 'frame119.jpg', 'frame12.jpg', 'frame120.jpg', 'frame121.jpg', 'frame122.jpg', 'frame123.jpg', 'frame124.jpg', 'frame125.jpg', 'frame126.jpg', 'frame127.jpg', 'frame128.jpg', 'frame129.jpg', 'frame13.jpg', 'frame130.jpg', 'frame131.jpg', 'frame132.jpg', 'frame133.jpg', 'frame134.jpg', 'frame135.jpg', 'frame136.jpg', 'frame137.jpg', 'frame138.jpg', 'frame139.jpg', 'frame14.jpg', 'frame140.jpg', 'frame141.jpg', 'frame142.jpg', 'frame143.jpg', 'frame144.jpg', 'frame145.jpg', 'frame146.jpg', 'frame147.jpg', 'frame148.jpg', 'frame149.jpg', 'frame15.jpg', 'frame150.jpg', 'frame151.jpg', 'frame152.jpg', 'frame153.jpg', 'frame154.jpg', 'frame155.jpg', 'frame156.jpg', 'frame157.jpg', 'frame158.jpg', 'frame159.jpg', 'frame16.jpg', 'frame160.jpg', 'frame161.jpg', 'frame162.jpg', 'frame163.jpg', 'frame164.jpg', 'frame165.jpg', 'frame166.jpg', 'frame167.jpg', 'frame168.jpg', 'frame169.jpg', 'frame17.jpg', 'frame170.jpg', 'frame171.jpg', 'frame172.jpg', 'frame173.jpg', 'frame174.jpg', 'frame175.jpg', 'frame176.jpg', 'frame177.jpg', 'frame178.jpg', 'frame179.jpg', 'frame18.jpg', 'frame180.jpg', 'frame181.jpg', 'frame182.jpg', 'frame183.jpg', 'frame184.jpg', 'frame185.jpg', 'frame186.jpg', 'frame187.jpg', 'frame188.jpg', 'frame189.jpg', 'frame19.jpg', 'frame190.jpg', 'frame191.jpg', 'frame192.jpg', 'frame193.jpg', 'frame194.jpg', 'frame195.jpg', 'frame196.jpg', 'frame197.jpg', 'frame198.j