# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("1.csv")
df.drop(["image_id","category_id","score"], axis = 1)
df["keypoints"].to_numpy()
a = np.array(df["keypoints"])
b = int(len(df)/51)
a2 = a.reshape(b,51)
a1 = pd.DataFrame(a2)
a3 =a1.rename(columns={0:'nose_x',1:'nose_y',2:'nose_s',3:'lEye_x',4:'lEye_y',5:'lEye_s',6:'rEye_x',7:'rEye_y',8:'rEye_s',9:'lEar_x',10:'lEar_y',
                       11:'lEar_s',12:'rEar_x',13:'rEar_y',14:'rEar_s',15:'lShoulder_x',16:'lShoulder_y',17:'lShoulder_s',18:'rShoulder_x',19:'rShoulder_y',20:'rShoulder_s',
                       21:'lElbow_x',22:'lElbow_y',23:'lElbow_s',24:'rElbow_x',25:'rElbow_y',26:'rElbow_s',27:'lWrist_x',28:'lWrist_y',29:'lWrist_s',30:'rWrist_x',
                       31:'rWrist_y',32:'rWrist_s',33:'lHip_x',34:'lHip_y',35:'lHip_s',36:'rHip_x',37:'rHip_y',38:'rHip_s',39:'lKnee_x',40:'lKnee_y',
                       41:'lKnee_s',42:'rKnee_x',43:'rKnee_y',44:'rKnee_s',45:'lAnkle_x',46:'lAnkle_y',47:'lAnkle_s',48:'rAnkle_x',49:'rAnkle_y',50:'rAnkle_s'})
a3
a3.to_csv("overhead.csv", index = False)

# %%
df = pd.read_csv("overhead.csv")
pd.set_option('display.max_columns', None)
df
# Out:
#          nose_x      nose_y    nose_s      lEye_x      lEye_y    lEye_s  \
# 0    559.055847  550.213135  0.901269  583.043396  526.225647  0.886451
# 1    561.225586  550.213135  0.902451  585.213074  526.225647  0.889844
# 2    562.989319  550.213135  0.902804  586.976868  526.225647  0.887901
# 3    557.054016  560.622437  0.938242  580.652222  525.225037  0.939210
# 4    548.734558  555.710632  0.935491  572.418152  532.027039  0.936274
# ..          ...         ...       ...         ...         ...       ...
# 595  584.473206  579.703735  0.870419  608.362610  555.814392  0.842236
# 596  586.959167  574.200623  0.857131  610.946594  550.213135  0.839436
# 597  588.489929  574.200623  0.840981  612.477356  550.213135  0.826579
# 598  578.573425  574.200623  0.834179  614.554626  550.213135  0.836858
# 599  578.561096  574.200623  0.841339  614.542419  550.213135  0.835318
#
#          rEye_x      rEye_y    rEye_s      lEar_x      lEar_y    lEar_s  \
# 0    523.074646  526.225647  0.911977  619.024597  538.219421  0.763849
# 1    525.244324  526.225647  0.899953  633.188110  538.219421  0.849193
# 2    527.008118  526.225647  0.920280  634.951843  538.219421  0.851018
# 3    521.656677  525.225037  0.932091  627.848694  537.024170  0.886959
# 4    525.050964  532.027039  0.955041  619.785217  543.868835  0.887004
# ..          ...         ...       ...         ...         ...       ...
# 595  560.583923  543.869751  0.902306  656.141174  567.759033  0.817633
# 596  562.971619  538.219421  0.864009  646.927917  562.206909  0.812024
# 597  552.508606  538.219421  0.853094  648.458679  562.206909  0.823201
# 598  554.585876  538.219421  0.848982  650.535950  562.206909  0.816723
# 599  554.573669  538.219421  0.855015  650.523621  562.206909  0.791809
#
#          rEar_x      rEar_y    rEar_s  lShoulder_x  lShoulder_y  lShoulder_s  \
# 0    499.087128  550.213135  0.651960   666.999634   694.138123     0.810967
# 1    501.256836  538.219421  0.717056   669.169373   694.138123     0.813867
# 2    491.026825  538.219421  0.773712   670.933167   694.138123     0.790622
# 3    486.259338  537.024170  0.689073   663.245911   702.211731     0.830793
# 4    489.525665  543.868835  0.731063   667.152405   697.812012     0.806802
# ..          ...         ...       ...          ...          ...          ...
# 595  524.749939  555.814392  0.691125   691.975159   711.094971     0.801523
# 596  526.990417  562.206909  0.676466   694.902893   706.131897     0.792356
# 597  516.527405  562.206909  0.709959   696.433655   706.131897     0.804154
# 598  518.604675  562.206909  0.692556   686.517151   706.131897     0.787925
# 599  506.598602  562.206909  0.724557   686.504944   706.131897     0.789832
#
#      rShoulder_x  rShoulder_y  rShoulder_s    lElbow_x    lElbow_y  lElbow_s  \
# 0     427.124603   682.144409     0.784025  798.930908  502.238159  0.886494
# 1     417.300537   682.144409     0.783155  813.094360  514.231873  0.873997
# 2     419.064301   682.144409     0.773650  814.858093  526.225647  0.917444
# 3     415.464661   690.412598     0.775943  816.634460  537.024170  0.888656
# 4     430.316742   697.812012     0.771504  821.095520  555.710632  0.941998
# ..           ...          ...          ...         ...         ...       ...
# 595   441.137299   711.094971     0.789593  859.200378  567.759033  0.953556
# 596   443.034088   706.131897     0.800398  850.821716  550.213135  0.969850
# 597   444.564850   694.138123     0.812035  852.352478  538.219421  0.946454
# 598   446.642120   694.138123     0.818957  842.435974  538.219421  0.950239
# 599   446.629852   694.138123     0.818911  842.423645  526.225647  0.931441
#
#        rElbow_x    rElbow_y  rElbow_s    lWrist_x    lWrist_y  lWrist_s  \
# 0    307.187103  502.238159  0.959049  810.924683  298.344360  0.833324
# 1    297.363037  514.231873  0.930744  813.094360  310.338135  0.810112
# 2    287.133087  514.231873  0.903584  802.864319  322.331879  0.796239
# 3    285.674438  525.225037  0.924816  804.835266  336.439270  0.853893
# 4    276.373535  543.868835  0.937600  809.253784  366.242035  0.918438
# ..          ...         ...       ...         ...         ...       ...
# 595  297.801361  555.814392  0.883537  859.200378  364.699829  0.870918
# 596  311.102875  538.219421  0.908576  850.821716  334.325623  0.849098
# 597  312.633636  526.225647  0.882456  852.352478  322.331879  0.867173
# 598  326.704620  514.231873  0.857722  854.429749  310.338135  0.849254
# 599  326.692352  514.231873  0.880989  854.417419  310.338135  0.856006
#
#        rWrist_x    rWrist_y  rWrist_s      lHip_x       lHip_y    lHip_s  \
# 0    331.174591  298.344360  0.855589  619.024597  1077.938110  0.722533
# 1    333.344299  310.338135  0.842217  609.200623  1077.938110  0.710615
# 2    335.108063  322.331879  0.799546  610.964417  1077.938110  0.724617
# 3    332.870911  336.439270  0.852684  616.049622  1079.783203  0.726129
# 4    335.582489  354.400269  0.815823  607.943481  1088.590820  0.717836
# ..          ...         ...       ...         ...          ...       ...
# 595  369.469330  352.755188  0.847544  632.251831  1117.213379  0.705983
# 596  359.077850  334.325623  0.845772  634.934143  1113.919434  0.713655
# 597  360.608612  322.331879  0.878955  636.464905  1113.919434  0.719634
# 598  362.685883  310.338135  0.899004  638.542175  1113.919434  0.733774
# 599  362.673615  310.338135  0.896241  638.529968  1113.919434  0.726492
#
#          rHip_x       rHip_y    rHip_s     lKnee_x      lKnee_y   lKnee_s  \
# 0    439.118378  1065.944336  0.726033  631.018372  1437.750610  0.875914
# 1    441.288086  1065.944336  0.721518  633.188110  1437.750610  0.865139
# 2    443.051849  1065.944336  0.734216  622.958069  1437.750610  0.866504
# 3    439.062927  1067.984009  0.753858  627.848694  1445.555664  0.867580
# 4    430.316742  1064.907227  0.747505  619.785217  1443.844360  0.870428
# ..          ...          ...       ...         ...          ...       ...
# 595  453.081940  1105.268677  0.750405  644.196594  1487.497803  0.826591
# 596  455.027863  1113.919434  0.743736  646.927917  1473.731934  0.825306
# 597  456.558624  1101.925659  0.729553  648.458679  1473.731934  0.806834
# 598  446.642120  1101.925659  0.720438  638.542175  1485.725586  0.819776
# 599  458.623627  1101.925659  0.715640  638.529968  1485.725586  0.814908
#
#         rKnee_x      rKnee_y   rKnee_s    lAnkle_x     lAnkle_y  lAnkle_s  \
# 0    367.155853  1437.750610  0.796471  619.024597  1761.581787  0.800676
# 1    369.325562  1437.750610  0.804643  621.194336  1761.581787  0.802536
# 2    371.089325  1437.750610  0.813220  622.958069  1761.581787  0.806372
# 3    368.268250  1433.756470  0.809154  616.049622  1764.131592  0.822348
# 4    359.266022  1443.844360  0.783674  619.785217  1763.572388  0.804713
# ..          ...          ...       ...         ...          ...       ...
# 595  381.414032  1463.608398  0.835609  632.251831  1798.058716  0.799125
# 596  383.065338  1473.731934  0.852660  634.934143  1797.562988  0.801370
# 597  384.596100  1473.731934  0.836350  636.464905  1797.562988  0.802708
# 598  386.673370  1461.738159  0.819897  638.542175  1797.562988  0.808259
# 599  386.661102  1461.738159  0.814897  638.529968  1797.562988  0.816305
#
#        rAnkle_x     rAnkle_y  rAnkle_s
# 0    343.168365  1749.588013  0.818179
# 1    345.338074  1749.588013  0.818527
# 2    347.101837  1749.588013  0.819445
# 3    344.669983  1752.332397  0.809765
# 4    347.424286  1751.730835  0.821605
# ..          ...          ...       ...
# 595  369.469330  1774.169434  0.832094
# 596  359.077850  1773.575562  0.830963
# 597  360.608612  1773.575562  0.840963
# 598  362.685883  1773.575562  0.826557
# 599  362.673615  1773.575562  0.823224
#
# [600 rows x 51 columns]

# %%
df['rLowerLegLen']=((df['rKnee_x']-df['rAnkle_x'])**2+(df['rKnee_y']-df['rAnkle_y'])**2)**.5
df['rLowerLegAng']=np.arctan2((df['rKnee_y']-df['rAnkle_y']),(df['rKnee_x']-df['rAnkle_x']))*180/3.14
df['rLowerLegScr']=(df['rKnee_s']*df['rAnkle_s'])**.5
df['lLowerLegLen']=((df['lKnee_x']-df['lAnkle_x'])**2+(df['lKnee_y']-df['lAnkle_y'])**2)**.5
df['lLowerLegAng']=np.arctan2((df['lKnee_y']-df['lAnkle_y']),(df['lKnee_x']-df['lAnkle_x']))*180/3.14
df['lLowerLegScr']=(df['lKnee_s']*df['lAnkle_s'])**.5
df['lUpperLegLen']=((df['lHip_x']-df['lKnee_x'])**2+(df['lHip_y']-df['lKnee_y'])**2)**.5
df['lUpperLegAng']=np.arctan2((df['lHip_y']-df['lKnee_y']),(df['lHip_x']-df['lKnee_x']))*180/3.14
df['lUpperLegScr']=(df['lKnee_s']*df['lHip_s'])**.5
df['rUpperLegLen']=((df['rHip_x']-df['rKnee_x'])**2+(df['rHip_y']-df['rKnee_y'])**2)**.5
df['rUpperLegAng']=np.arctan2((df['rHip_y']-df['rKnee_y']),(df['rHip_x']-df['rKnee_x']))*180/3.14
df['rUpperLegScr']=(df['rKnee_s']*df['rHip_s'])**.5

# %%
df['rBackLen']=((df['rHip_x']-df['rShoulder_x'])**2+(df['rHip_y']-df['rShoulder_y'])**2)**.5
df['rBackAng']=np.arctan2((df['rShoulder_y']-df['rHip_y']),(df['rShoulder_x']-df['rHip_x']))*180/3.14
df['rBackScr']=(df['rHip_s']*df['rShoulder_s'])**.5
df['lBackLen']=((df['lHip_x']-df['lShoulder_x'])**2+(df['lHip_y']-df['lShoulder_y'])**2)**.5
df['lBackAng']=np.arctan2((df['lShoulder_y']-df['lHip_y']),(df['lShoulder_x']-df['lHip_x']))*180/3.14
df['lBackScr']=(df['lHip_s']*df['lShoulder_s'])**.5
df['mBackLen']=((((df['rHip_x']+df['lHip_x'])/2)-df['nose_x'])**2+(((df['rHip_y']+df['lHip_y'])/2)-df['nose_y'])**2)**.5
df['mBackAng']=np.arctan2((df['nose_y']-((df['rHip_y']+df['lHip_y'])/2)),(df['nose_x']-((df['rHip_x']+df['lHip_x'])/2)))*180/3.14
df['mBackScr']=(((df['lHip_s']*df['lHip_s'])**.5)*df['nose_s'])**.5

# %%
df['bodyLen']=((((df['rAnkle_x']+df['lAnkle_x'])/2)-df['nose_x'])**2+(((df['rAnkle_y']+df['lAnkle_y'])/2)-df['nose_y'])**2)**.5
df['bodyAng']=np.arctan((df['nose_y']-((df['rAnkle_y']+df['lAnkle_y'])/2))/(df['nose_x']-((df['rAnkle_x']+df['lAnkle_x'])/2)))*180/3.14
df['bodykScr']=(((df['lAnkle_s']*df['lAnkle_s'])**.5)*df['nose_s'])**.5

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df[['nose_x', 'rShoulder_x', 'rElbow_x', 'rWrist_x',
       'lShoulder_x', 'lElbow_x', 'lWrist_x', 'rHip_x', 'rKnee_x', 'rAnkle_x',
       'lHip_x', 'lKnee_x', 'lAnkle_x', 'rEye_x', 'lEye_x', 'rEar_x', 'lEar_x',
       'nose_y', 'rShoulder_y', 'rElbow_y', 'rWrist_y',
       'lShoulder_y', 'lElbow_y', 'lWrist_y', 'rHip_y', 'rKnee_y', 'rAnkle_y',
       'lHip_y', 'lKnee_y', 'lAnkle_y', 'rEye_y', 'lEye_y', 'rEar_y', 'lEar_y',
       'rLowerLegLen', 'lLowerLegLen', 'lUpperLegLen', 'rUpperLegLen',
       'rBackLen', 'lBackLen', 'mBackLen', 'bodyLen']] =scaler.fit_transform(df[['nose_x', 'rShoulder_x', 'rElbow_x', 'rWrist_x',
       'lShoulder_x', 'lElbow_x', 'lWrist_x', 'rHip_x', 'rKnee_x', 'rAnkle_x',
       'lHip_x', 'lKnee_x', 'lAnkle_x', 'rEye_x', 'lEye_x', 'rEar_x', 'lEar_x',
       'nose_y', 'rShoulder_y', 'rElbow_y', 'rWrist_y',
       'lShoulder_y', 'lElbow_y', 'lWrist_y', 'rHip_y', 'rKnee_y', 'rAnkle_y',
       'lHip_y', 'lKnee_y', 'lAnkle_y', 'rEye_y', 'lEye_y', 'rEar_y', 'lEar_y',
       'rLowerLegLen', 'lLowerLegLen', 'lUpperLegLen', 'rUpperLegLen',
       'rBackLen', 'lBackLen', 'mBackLen', 'bodyLen']])

# %%
"""'rLowerHandLen', 'lLowerHandLen',
       'lUpperHandLen', 'rUpperHandLen',"""
# Out:
# "'rLowerHandLen', 'lLowerHandLen',\n       'lUpperHandLen', 'rUpperHandLen',"

# %%
 df["in"]=df.index

# %%
 for i in df.columns:
    if i[-1]=='s':
        df=df[df[i]>0.3]

# %%
df.count()
# Out:
# nose_x      599
# nose_y      599
# nose_s      599
# lEye_x      599
# lEye_y      599
#            ...
# mBackScr    599
# bodyLen     599
# bodyAng     599
# bodykScr    599
# in          599
# Length: 76, dtype: int64

# %%
plt.scatter(df["in"],df["lShoulder_y"])

# %%
#SAVING REFRENCE DATA
ref_mm={}
for i in df.columns:
    if i[-1]=='g':
        ref_mm[i+'_max']=df[i].max()
        ref_mm[i+'_min']=df[i].min()
ref_mm
# Out:
# {'rLowerLegAng_max': -83.46036193493885,
#  'rLowerLegAng_min': -90.04564930671381,
#  'lLowerLegAng_max': -86.09845209378703,
#  'lLowerLegAng_min': -92.16781555999225,
#  'lUpperLegAng_max': -90.04564930671381,
#  'lUpperLegAng_min': -94.94722559775153,
#  'rUpperLegAng_max': -77.31483328902071,
#  'rUpperLegAng_min': -82.3456930751793,
#  'rBackAng_max': -88.25482284048725,
#  'rBackAng_min': -93.7389195236375,
#  'lBackAng_max': -76.0022767783976,
#  'lBackAng_min': -83.52254484819616,
#  'mBackAng_max': -83.57254529635823,
#  'mBackAng_min': -90.04564592411981,
#  'bodyAng_max': -85.09480458288982,
#  'bodyAng_min': -88.25483127768902}

# %%
min_a={}
max_a={}
min_l={}
for i in df.columns:
    if i[-1]=='g':
        min_a[i]=df[i].min()
        max_a[i]=df[i].max()
    if i[-1]=='n':
        min_l[i]=df[i].min()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

test=pd.read_csv('overhead.csv')
pd.set_option('display.max_columns', None)
print(len(test))
ind=len(test)
test['rLowerLegLen']=((test['rKnee_x']-test['rAnkle_x'])**2+(test['rKnee_y']-test['rAnkle_y'])**2)**.5
test['rLowerLegAng']=np.arctan2((test['rKnee_y']-test['rAnkle_y']),(test['rKnee_x']-test['rAnkle_x']))*180/3.14
test['rLowerLegScr']=(test['rKnee_s']*test['rAnkle_s'])**.5
test['lLowerLegLen']=((test['lKnee_x']-test['lAnkle_x'])**2+(test['lKnee_y']-test['lAnkle_y'])**2)**.5
test['lLowerLegAng']=np.arctan2((test['lKnee_y']-test['lAnkle_y']),(test['lKnee_x']-test['lAnkle_x']))*180/3.14
test['lLowerLegScr']=(test['lKnee_s']*test['lAnkle_s'])**.5
test['lUpperLegLen']=((test['lHip_x']-test['lKnee_x'])**2+(test['lHip_y']-test['lKnee_y'])**2)**.5
test['lUpperLegAng']=np.arctan2((test['lHip_y']-test['lKnee_y']),(test['lHip_x']-test['lKnee_x']))*180/3.14
test['lUpperLegScr']=(test['lKnee_s']*test['lHip_s'])**.5
test['rUpperLegLen']=((test['rHip_x']-test['rKnee_x'])**2+(test['rHip_y']-test['rKnee_y'])**2)**.5
test['rUpperLegAng']=np.arctan2((test['rHip_y']-test['rKnee_y']),(test['rHip_x']-test['rKnee_x']))*180/3.14
test['rUpperLegScr']=(test['rKnee_s']*test['rHip_s'])**.5

test['rBackLen']=((test['rHip_x']-test['rShoulder_x'])**2+(test['rHip_y']-test['rShoulder_y'])**2)**.5
test['rBackAng']=np.arctan2((test['rShoulder_y']-test['rHip_y']),(test['rShoulder_x']-test['rHip_x']))*180/3.14
test['rBackScr']=(test['rHip_s']*test['rShoulder_s'])**.5
test['lBackLen']=((test['lHip_x']-test['lShoulder_x'])**2+(test['lHip_y']-test['lShoulder_y'])**2)**.5
test['lBackAng']=np.arctan2((test['lShoulder_y']-test['lHip_y']),(test['lShoulder_x']-test['lHip_x']))*180/3.14
test['lBackScr']=(test['lHip_s']*test['lShoulder_s'])**.5
test['mBackLen']=((((test['rHip_x']+test['lHip_x'])/2)-test['nose_x'])**2+(((test['rHip_y']+test['lHip_y'])/2)-test['nose_y'])**2)**.5
test['mBackAng']=np.arctan2((test['nose_y']-((test['rHip_y']+test['lHip_y'])/2)),(test['nose_x']-((test['rHip_x']+test['lHip_x'])/2)))*180/3.14
test['mBackScr']=(((test['lHip_s']*test['lHip_s'])**.5)*test['nose_s'])**.5

test['bodyLen']=((((test['rAnkle_x']+test['lAnkle_x'])/2)-test['nose_x'])**2+(((test['rAnkle_y']+test['lAnkle_y'])/2)-test['nose_y'])**2)**.5
test['bodyAng']=np.arctan((test['nose_y']-((test['rAnkle_y']+test['lAnkle_y'])/2))/(test['nose_x']-((test['rAnkle_x']+test['lAnkle_x'])/2)))*180/3.14
test['bodykScr']=(((test['lAnkle_s']*test['lAnkle_s'])**.5)*test['nose_s'])**.5

test=test.drop(columns=['rElbow_s', 'rWrist_s', 'lElbow_s', 'lWrist_s', 'rEye_s', 'lEye_s', 'rEar_s', 'lEar_s'])
test.head()

#test.to_csv('Squats_m.csv')

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
test[['nose_x', 'rShoulder_x', 'rElbow_x', 'rWrist_x',
       'lShoulder_x', 'lElbow_x', 'lWrist_x', 'rHip_x', 'rKnee_x', 'rAnkle_x',
       'lHip_x', 'lKnee_x', 'lAnkle_x', 'rEye_x', 'lEye_x', 'rEar_x', 'lEar_x',
       'nose_y', 'rShoulder_y', 'rElbow_y', 'rWrist_y',
       'lShoulder_y', 'lElbow_y', 'lWrist_y', 'rHip_y', 'rKnee_y', 'rAnkle_y',
       'lHip_y', 'lKnee_y', 'lAnkle_y', 'rEye_y', 'lEye_y', 'rEar_y', 'lEar_y',
       'rLowerLegLen', 'lLowerLegLen', 'lUpperLegLen', 'rUpperLegLen',
       'rBackLen', 'lBackLen', 'mBackLen', 'bodyLen']] =scaler.fit_transform(test[['nose_x', 'rShoulder_x', 'rElbow_x', 'rWrist_x',
       'lShoulder_x', 'lElbow_x', 'lWrist_x', 'rHip_x', 'rKnee_x', 'rAnkle_x',
       'lHip_x', 'lKnee_x', 'lAnkle_x', 'rEye_x', 'lEye_x', 'rEar_x', 'lEar_x',
       'nose_y', 'rShoulder_y', 'rElbow_y', 'rWrist_y',
       'lShoulder_y', 'lElbow_y', 'lWrist_y', 'rHip_y', 'rKnee_y', 'rAnkle_y',
       'lHip_y', 'lKnee_y', 'lAnkle_y', 'rEye_y', 'lEye_y', 'rEar_y', 'lEar_y',
       'rLowerLegLen', 'lLowerLegLen', 'lUpperLegLen', 'rUpperLegLen',
       'rBackLen', 'lBackLen', 'mBackLen', 'bodyLen']])

"""'rLowerHandLen', 'lLowerHandLen',
       'lUpperHandLen', 'rUpperHandLen',"""

test["in"]=test.index

for i in test.columns:
    if i[-1]=='s':
        test=test[test[i]>0.35]

len(test)
# Out:
# 600
# 600

# %%
#SAVING EVERY RESOLUTIONS MIN AND MAX FOR COMPARISON
from scipy.signal import argrelextrema
min_max={}
n=20
for i in test.columns:
    if i[-1]!='x':
        test['min'] = test.iloc[argrelextrema(test[i].values, np.less_equal, order=n)[0]][i]
        test['max'] = test.iloc[argrelextrema(test[i].values, np.greater_equal, order=n)[0]][i]
        # Plot results
        plt.scatter(test.index, test['min'], c='r')
        plt.scatter(test.index, test['max'], c='g')
        #x=test['min'].values
        #min_max[i+'_min']=x[np.logical_not(np.isnan(x))]
        #y=test['max'].values
        #min_max[i+'_max']=y[np.logical_not(np.isnan(y))]
        plt.plot(test.index, test[i])
        print(i)
        print('Min',test['min'].count())
        print('Max:',test['max'].count())
        min_max[i+'_min']=test[['min']]
        min_max[i+'_max']=test[['max']]
        min_max[i+'_min']=min_max[i+'_min'].dropna()
        min_max[i+'_max']=min_max[i+'_max'].dropna()
        min_max[i+'_min'].columns = ['m']
        min_max[i+'_max'].columns = ['m']
        plt.show()
# Out:
# nose_y
# Min 32
# Max: 15
# nose_s
# Min 16
# Max: 16
# lEye_y
# Min 28
# Max: 13
# rEye_y
# Min 31
# Max: 11
# lEar_y
# Min 35
# Max: 13
# rEar_y
# Min 17
# Max: 12
# lShoulder_y
# Min 72
# Max: 13
# lShoulder_s
# Min 15
# Max: 16
# rShoulder_y
# Min 93
# Max: 13
# rShoulder_s
# Min 18
# Max: 16
# lElbow_y
# Min 42
# Max: 13
# rElbow_y
# Min 40
# Max: 13
# lWrist_y
# Min 43
# Max: 13
# rWrist_y
# Min 25
# Max: 13
# lHip_y
# Min 13
# Max: 19
# lHip_s
# Min 13
# Max: 18
# rHip_y
# Min 14
# Max: 18
# rHip_s
# Min 13
# Max: 15
# lKnee_y
# Min 16
# Max: 18
# lKnee_s
# Min 16
# Max: 14
# rKnee_y
# Min 22
# Max: 17
# rKnee_s
# Min 16
# Max: 14
# lAnkle_y
# Min 25
# Max: 17
# lAnkle_s
# Min 11
# Max: 16
# rAnkle_y
# Min 36
# Max: 15
# rAnkle_s
# Min 15
# Max: 14
# rLowerLegLen
# Min 16
# Max: 11
# rLowerLegAng
# Min 17
# Max: 17
# rLowerLegScr
# Min 15
# Max: 15
# lLowerLegLen
# Min 12
# Max: 13
# lLowerLegAng
# Min 186
# Max: 17
# lLowerLegScr
# Min 15
# Max: 14
# lUpperLegLen
# Min 17
# Max: 14
# lUpperLegAng
# Min 19
# Max: 51
# lUpperLegScr
# Min 13
# Max: 14
# rUpperLegLen
# Min 19
# Max: 16
# rUpperLegAng
# Min 13
# Max: 18
# rUpperLegScr
# Min 14
# Max: 15
# rBackLen
# Min 13
# Max: 40
# rBackAng
# Min 19
# Max: 114
# rBackScr
# Min 13
# Max: 15
# lBackLen
# Min 13
# Max: 21
# lBackAng
# Min 22
# Max: 13
# lBackScr
# Min 13
# Max: 17
# mBackLen
# Min 15
# Max: 16
# mBackAng
# Min 15
# Max: 13
# mBackScr
# Min 13
# Max: 15
# bodyLen
# Min 15
# Max: 12
# bodyAng
# Min 10
# Max: 14
# bodykScr
# Min 16
# Max: 14
# in
# Min 1
# Max: 1

# %%
er=pd.DataFrame(index=np.arange(ind), columns=['error'])
er=er.fillna(0)

# %%
ref_mm={}
for i in test.columns:
    if (i[-1]=='x') or (i[-1]=='y') or (i[-1]=='s') or (i[-1]=='g') or (i[-1]=='r') or (i[-1]=='n') :
        ref_mm[i+'_max']=test[i].max()
        ref_mm[i+'_min']=test[i].min()
ref_mm
# Out:
# {'nose_x_max': 1.0000000000000009,
#  'nose_x_min': 0.0,
#  'nose_y_max': 1.0,
#  'nose_y_min': 0.0,
#  'nose_s_max': 0.9784754514694214,
#  'nose_s_min': 0.8199998140335083,
#  'lEye_x_max': 1.0,
#  'lEye_x_min': 0.0,
#  'lEye_y_max': 1.0,
#  'lEye_y_min': 0.0,
#  'rEye_x_max': 1.0,
#  'rEye_x_min': 0.0,
#  'rEye_y_max': 1.0,
#  'rEye_y_min': 0.0,
#  'lEar_x_max': 1.0,
#  'lEar_x_min': 0.0,
#  'lEar_y_max': 1.0,
#  'lEar_y_min': 0.0,
#  'rEar_x_max': 1.0,
#  'rEar_x_min': 0.0,
#  'rEar_y_max': 1.0,
#  'rEar_y_min': 0.0,
#  'lShoulder_x_max': 1.0,
#  'lShoulder_x_min': 0.0,
#  'lShoulder_y_max': 1.0,
#  'lShoulder_y_min': 0.0,
#  'lShoulder_s_max': 0.8572777509689331,
#  'lShoulder_s_min': 0.7599127292633057,
#  'rShoulder_x_max': 1.0,
#  'rShoulder_x_min': 0.0,
#  'rShoulder_y_max': 1.0,
#  'rShoulder_y_min': 0.0,
#  'rShoulder_s_max': 0.873914897441864,
#  'rShoulder_s_min': 0.7503048777580261,
#  'lElbow_x_max': 0.9999999999999991,
#  'lElbow_x_min': 0.0,
#  'lElbow_y_max': 1.0,
#  'lElbow_y_min': 0.0,
#  'rElbow_x_max': 1.0,
#  'rElbow_x_min': 0.0,
#  'rElbow_y_max': 0.9999999999999998,
#  'rElbow_y_min': 0.0,
#  'lWrist_x_max': 1.0,
#  'lWrist_x_min': 0.0,
#  'lWrist_y_max': 1.0,
#  'lWrist_y_min': 0.0,
#  'rWrist_x_max': 1.0,
#  'rWrist_x_min': 0.0,
#  'rWrist_y_max': 0.9999999999999999,
#  'rWrist_y_min': 0.0,
#  'lHip_x_max': 1.0,
#  'lHip_x_min': 0.0,
#  'lHip_y_max': 1.0,
#  'lHip_y_min': 0.0,
#  'lHip_s_max': 0.7842257022857666,
#  'lHip_s_min': 0.597578227519989,
#  'rHip_x_max': 1.0,
#  'rHip_x_min': 0.0,
#  'rHip_y_max': 0.9999999999999982,
#  'rHip_y_min': 0.0,
#  'rHip_s_max': 0.7723949551582336,
#  'rHip_s_min': 0.6678022742271423,
#  'lKnee_x_max': 1.0,
#  'lKnee_x_min': 0.0,
#  'lKnee_y_max': 1.0,
#  'lKnee_y_min': 0.0,
#  'lKnee_s_max': 0.8759143352508545,
#  'lKnee_s_min': 0.766373872756958,
#  'rKnee_x_max': 1.0,
#  'rKnee_x_min': 0.0,
#  'rKnee_y_max': 1.0,
#  'rKnee_y_min': 0.0,
#  'rKnee_s_max': 0.8548793792724609,
#  'rKnee_s_min': 0.7607521414756775,
#  'lAnkle_x_max': 1.0,
#  'lAnkle_x_min': 0.0,
#  'lAnkle_y_max': 1.0,
#  'lAnkle_y_min': 0.0,
#  'lAnkle_s_max': 0.8487023115158081,
#  'lAnkle_s_min': 0.7693809270858765,
#  'rAnkle_x_max': 1.0,
#  'rAnkle_x_min': 0.0,
#  'rAnkle_y_max': 1.0,
#  'rAnkle_y_min': 0.0,
#  'rAnkle_s_max': 0.8492780923843384,
#  'rAnkle_s_min': 0.7767435312271118,
#  'rLowerLegLen_max': 1.0,
#  'rLowerLegLen_min': 0.0,
#  'rLowerLegAng_max': -83.46036193493885,
#  'rLowerLegAng_min': -90.04564930671381,
#  'rLowerLegScr_max': 0.8496890977233483,
#  'rLowerLegScr_min': 0.7869343770407634,
#  'lLowerLegLen_max': 1.0,
#  'lLowerLegLen_min': 0.0,
#  'lLowerLegAng_max': -86.09845209378703,
#  'lLowerLegAng_min': -92.16781555999225,
#  'lLowerLegScr_max': 0.8453581694379075,
#  'lLowerLegScr_min': 0.7732361469429012,
#  'lUpperLegLen_max': 1.0,
#  'lUpperLegLen_min': 0.0,
#  'lUpperLegAng_max': -90.04564930671381,
#  'lUpperLegAng_min': -94.94722559775153,
#  'lUpperLegScr_max': 0.8203494629373952,
#  'lUpperLegScr_min': 0.6837948645812726,
#  'rUpperLegLen_max': 1.0,
#  'rUpperLegLen_min': 0.0,
#  'rUpperLegAng_max': -77.31483328902071,
#  'rUpperLegAng_min': -82.3456930751793,
#  'rUpperLegScr_max': 0.7994841749065508,
#  'rUpperLegScr_min': 0.7326582128962811,
#  'rBackLen_max': 0.9999999999999996,
#  'rBackLen_min': 0.0,
#  'rBackAng_max': -88.25482284048725,
#  'rBackAng_min': -93.7389195236375,
#  'rBackScr_max': 0.8075744543000042,
#  'rBackScr_min': 0.7231666078437351,
#  'lBackLen_max': 0.9999999999999996,
#  'lBackLen_min': 0.0,
#  'lBackAng_max': -76.0022767783976,
#  'lBackAng_min': -83.52254484819616,
#  'lBackScr_max': 0.7983934813948532,
#  'lBackScr_min': 0.6857807397318899,
#  'mBackLen_max': 0.9999999999999991,
#  'mBackLen_min': 0.0,
#  'mBackAng_max': -83.57254529635823,
#  'mBackAng_min': -90.04564592411981,
#  'mBackScr_max': 0.863776026614544,
#  'mBackScr_min': 0.7160963325281184,
#  'bodyLen_max': 1.0,
#  'bodyLen_min': 0.0,
#  'bodyAng_max': -85.09480458288982,
#  'bodyAng_min': -88.25483127768902,
#  'bodykScr_max': 0.8975221717490266,
#  'bodykScr_min': 0.8055849152729183,
#  'in_max': 599,
#  'in_min': 0,
#  'min_max': 0.0,
#  'min_min': 0.0,
#  'max_max': 599.0,
#  'max_min': 599.0}

# %%
min_max
# Out:
# {'nose_y_min':             m
#  16   0.230020
#  56   0.150101
#  78   0.151998
#  142  0.000000
#  143  0.000000
#  144  0.000000
#  145  0.000000
#  146  0.000000
#  147  0.000000
#  148  0.000000
#  149  0.000000
#  150  0.000000
#  189  0.000000
#  192  0.000000
#  259  0.316074
#  306  0.312848
#  348  0.213147
#  372  0.258501
#  373  0.258501
#  374  0.258501
#  376  0.258501
#  439  0.206339
#  506  0.258501
#  507  0.258501
#  508  0.258501
#  509  0.258501
#  510  0.258501
#  511  0.258501
#  512  0.258501
#  513  0.258501
#  514  0.258501
#  564  0.412560,
#  'nose_y_max':             m
#  36   0.570680
#  99   0.517004
#  100  0.517004
#  175  0.466803
#  237  0.775505
#  238  0.775505
#  239  0.775505
#  240  0.775505
#  274  0.703890
#  319  0.791290
#  384  0.676905
#  409  0.777134
#  494  0.833261
#  533  0.715789
#  587  1.000000,
#  'nose_s_min':             m
#  17   0.864774
#  51   0.860575
#  98   0.858632
#  161  0.840779
#  209  0.859643
#  236  0.824275
#  284  0.840542
#  307  0.852485
#  332  0.820000
#  359  0.855352
#  403  0.860238
#  442  0.853672
#  484  0.861997
#  526  0.861785
#  555  0.839484
#  580  0.827494,
#  'nose_s_max':             m
#  8    0.957798
#  57   0.961926
#  103  0.957130
#  130  0.936680
#  156  0.962629
#  183  0.960840
#  204  0.965264
#  232  0.978475
#  279  0.947109
#  337  0.962473
#  380  0.955673
#  429  0.968457
#  475  0.955880
#  520  0.974936
#  565  0.961173
#  593  0.966109,
#  'lEye_y_min':             m
#  10   0.156472
#  67   0.107306
#  142  0.000000
#  143  0.000000
#  144  0.000000
#  145  0.000000
#  146  0.000000
#  147  0.000000
#  148  0.000000
#  149  0.000000
#  150  0.000000
#  192  0.000000
#  231  0.402558
#  293  0.240602
#  349  0.186232
#  374  0.242828
#  440  0.178850
#  506  0.242828
#  507  0.242828
#  508  0.242828
#  509  0.242828
#  510  0.242828
#  511  0.242828
#  512  0.242828
#  513  0.242828
#  514  0.242828
#  515  0.242828
#  547  0.396889,
#  'lEye_y_max':             m
#  36   0.586946
#  110  0.508241
#  178  0.416749
#  239  0.728484
#  267  0.641060
#  320  0.720858
#  364  0.672818
#  412  0.645774
#  448  0.516866
#  497  0.758759
#  529  0.673279
#  555  0.728484
#  587  1.000000,
#  'rEye_y_min':             m
#  10   0.231957
#  75   0.158156
#  139  0.000000
#  189  0.051529
#  190  0.051529
#  191  0.051529
#  192  0.051529
#  193  0.051529
#  194  0.051529
#  234  0.400826
#  293  0.328967
#  352  0.208669
#  374  0.331535
#  375  0.331535
#  376  0.331535
#  438  0.187723
#  506  0.331535
#  507  0.331535
#  508  0.331535
#  509  0.331535
#  510  0.331535
#  511  0.331535
#  512  0.331535
#  513  0.331535
#  514  0.331535
#  515  0.331535
#  549  0.416929
#  596  0.611540
#  597  0.611540
#  598  0.611540
#  599  0.611540,
#  'rEye_y_max':             m
#  11   0.513990
#  40   0.627701
#  102  0.543947
#  229  0.776315
#  273  0.756684
#  320  0.882750
#  364  0.827355
#  411  0.762886
#  495  0.879965
#  541  0.792874
#  592  1.000000,
#  'lEar_y_min':             m
#  8    0.060950
#  51   0.096365
#  103  0.091162
#  151  0.000000
#  189  0.096365
#  190  0.096365
#  191  0.096365
#  192  0.096365
#  193  0.096365
#  194  0.096365
#  195  0.096365
#  196  0.096365
#  240  0.375658
#  241  0.375658
#  294  0.275284
#  326  0.295299
#  352  0.191064
#  425  0.096365
#  460  0.303940
#  506  0.375658
#  507  0.375658
#  508  0.375658
#  509  0.375658
#  510  0.375658
#  511  0.375658
#  512  0.375658
#  513  0.375658
#  514  0.375658
#  515  0.375658
#  550  0.375658
#  559  0.375658
#  596  0.654951
#  597  0.654951
#  598  0.654951
#  599  0.654951,
#  'lEar_y_max':             m
#  36   0.712945
#  84   0.535690
#  110  0.635862
#  182  0.648907
#  224  0.908947
#  252  0.794608
#  320  0.876498
#  364  0.822126
#  407  0.765925
#  434  0.813953
#  494  0.996644
#  543  0.890502
#  584  1.000000,
#  'rEar_y_min':             m
#  3    0.221280
#  71   0.135351
#  122  0.122440
#  143  0.000000
#  146  0.000000
#  147  0.000000
#  148  0.000000
#  188  0.148335
#  232  0.509564
#  312  0.317078
#  336  0.268876
#  423  0.245773
#  424  0.245773
#  425  0.245773
#  515  0.245773
#  548  0.489169
#  595  0.606323,
#  'rEar_y_max':             m
#  34   0.671228
#  113  0.613746
#  227  0.811545
#  251  0.794777
#  272  0.804165
#  296  0.664895
#  324  0.739972
#  387  0.759210
#  456  0.713111
#  491  0.901024
#  541  0.840712
#  586  1.000000,
#  'lShoulder_y_min':             m
#  0    0.006727
#  1    0.006727
#  2    0.006727
#  53   0.089281
#  92   0.006727
#  ..        ...
#  559  0.217768
#  596  0.217768
#  597  0.217768
#  598  0.217768
#  599  0.217768
#
#  [72 rows x 1 columns],
#  'lShoulder_y_max':             m
#  30   0.755980
#  80   0.670096
#  118  0.674941
#  176  0.729541
#  222  0.911272
#  268  0.939821
#  315  0.886686
#  359  0.799735
#  404  0.906118
#  449  0.804202
#  492  1.000000
#  534  0.949056
#  582  0.972166,
#  'lShoulder_s_min':             m
#  24   0.760297
#  87   0.783260
#  135  0.777842
#  185  0.781649
#  249  0.762137
#  270  0.777762
#  318  0.765024
#  342  0.774449
#  363  0.773730
#  384  0.772365
#  408  0.766536
#  450  0.778428
#  497  0.771155
#  534  0.764910
#  582  0.759913,
#  'lShoulder_s_max':             m
#  3    0.830793
#  29   0.857278
#  72   0.836247
#  93   0.837737
#  117  0.827117
#  163  0.830406
#  218  0.849755
#  266  0.856384
#  289  0.830640
#  312  0.828051
#  354  0.833769
#  401  0.835331
#  465  0.829182
#  525  0.838899
#  567  0.821359
#  589  0.823763,
#  'rShoulder_y_min':             m
#  0    0.179891
#  1    0.179891
#  2    0.179891
#  47   0.179891
#  48   0.179891
#  ..        ...
#  557  0.359781
#  558  0.359781
#  597  0.359781
#  598  0.359781
#  599  0.359781
#
#  [93 rows x 1 columns],
#  'rShoulder_y_max':             m
#  30   0.840298
#  77   0.720224
#  126  0.746587
#  173  0.777354
#  223  0.935632
#  269  0.952808
#  314  0.835140
#  355  0.859426
#  402  1.000000
#  455  0.786975
#  493  0.998713
#  539  0.975329
#  581  0.991325,
#  'rShoulder_s_min':             m
#  15   0.765464
#  36   0.760160
#  60   0.763298
#  83   0.752782
#  116  0.768224
#  181  0.764751
#  226  0.763925
#  273  0.760669
#  299  0.760063
#  336  0.765166
#  357  0.774726
#  389  0.750305
#  427  0.764711
#  473  0.767879
#  500  0.752528
#  538  0.759368
#  561  0.765918
#  594  0.762539,
#  'rShoulder_s_max':             m
#  7    0.873915
#  42   0.844356
#  79   0.836919
#  105  0.860862
#  138  0.857282
#  221  0.862571
#  259  0.860316
#  293  0.861670
#  323  0.868368
#  383  0.867491
#  428  0.840944
#  455  0.843915
#  479  0.847313
#  518  0.841091
#  553  0.830195
#  591  0.821645,
#  'lElbow_y_min':             m
#  0    0.030221
#  48   0.060443
#  49   0.060443
#  50   0.060443
#  51   0.060443
#  95   0.030221
#  96   0.030221
#  97   0.030221
#  144  0.060443
#  145  0.060443
#  146  0.060443
#  147  0.060443
#  190  0.000000
#  191  0.000000
#  192  0.000000
#  193  0.000000
#  194  0.000000
#  195  0.000000
#  236  0.060443
#  237  0.060443
#  238  0.060443
#  239  0.060443
#  240  0.060443
#  285  0.030221
#  330  0.060443
#  331  0.060443
#  373  0.090664
#  374  0.090664
#  375  0.090664
#  376  0.090664
#  377  0.090664
#  419  0.030221
#  420  0.030221
#  421  0.030221
#  466  0.000000
#  467  0.000000
#  509  0.000000
#  510  0.000000
#  553  0.030221
#  554  0.030221
#  555  0.030221
#  599  0.090664,
#  'lElbow_y_max':             m
#  29   0.934542
#  76   0.948720
#  126  0.990276
#  173  0.994740
#  220  0.962888
#  266  0.956606
#  311  0.991796
#  356  0.948000
#  402  1.000000
#  446  0.988022
#  491  0.912099
#  536  0.961220
#  581  0.991969,
#  'rElbow_y_min':             m
#  0    0.088420
#  48   0.058946
#  49   0.058946
#  94   0.058946
#  95   0.058946
#  96   0.058946
#  97   0.058946
#  144  0.058946
#  145  0.058946
#  146  0.058946
#  147  0.058946
#  192  0.000000
#  193  0.000000
#  194  0.000000
#  236  0.088420
#  237  0.088420
#  238  0.088420
#  239  0.088420
#  282  0.088420
#  283  0.088420
#  284  0.088420
#  285  0.088420
#  331  0.088420
#  374  0.088420
#  375  0.088420
#  420  0.058946
#  421  0.058946
#  464  0.029473
#  465  0.029473
#  466  0.029473
#  467  0.029473
#  468  0.029473
#  508  0.029473
#  509  0.029473
#  510  0.029473
#  511  0.029473
#  553  0.029473
#  554  0.029473
#  598  0.117893
#  599  0.117893,
#  'rElbow_y_max':             m
#  28   0.931241
#  76   0.930933
#  125  0.955136
#  173  0.948928
#  220  0.972050
#  266  0.965861
#  311  0.973263
#  357  0.940710
#  401  1.000000
#  446  0.942169
#  492  0.879566
#  535  0.959823
#  579  0.980795,
#  'lWrist_y_min':             m
#  0    0.053349
#  48   0.053349
#  49   0.053349
#  50   0.053349
#  51   0.053349
#  94   0.026675
#  95   0.026675
#  96   0.026675
#  97   0.026675
#  144  0.053349
#  145  0.053349
#  146  0.053349
#  147  0.053349
#  191  0.000000
#  192  0.000000
#  193  0.000000
#  237  0.053349
#  238  0.053349
#  239  0.053349
#  283  0.053349
#  284  0.053349
#  285  0.053349
#  286  0.053349
#  330  0.080024
#  331  0.080024
#  332  0.080024
#  333  0.080024
#  373  0.106698
#  374  0.106698
#  375  0.106698
#  376  0.106698
#  420  0.026675
#  421  0.026675
#  422  0.026675
#  466  0.000000
#  509  0.000000
#  510  0.000000
#  511  0.000000
#  553  0.000000
#  554  0.000000
#  555  0.000000
#  598  0.080024
#  599  0.080024,
#  'lWrist_y_max':             m
#  28   0.915385
#  76   0.956103
#  128  0.957236
#  173  0.923007
#  219  0.953980
#  264  0.941279
#  312  0.974131
#  356  0.931269
#  401  1.000000
#  447  0.952524
#  492  0.895470
#  535  0.917998
#  581  0.956878,
#  'rWrist_y_min':             m
#  0    0.106068
#  48   0.079551
#  49   0.079551
#  95   0.053034
#  96   0.053034
#  145  0.053034
#  192  0.000000
#  193  0.000000
#  237  0.106068
#  238  0.106068
#  283  0.106068
#  284  0.106068
#  331  0.106068
#  374  0.106068
#  419  0.079551
#  420  0.079551
#  421  0.079551
#  465  0.026517
#  466  0.026517
#  467  0.026517
#  509  0.026517
#  510  0.026517
#  554  0.000000
#  598  0.132585
#  599  0.132585,
#  'rWrist_y_max':             m
#  28   0.939535
#  76   0.931632
#  126  0.965928
#  173  0.970587
#  218  0.959381
#  264  0.988751
#  312  0.974246
#  356  0.978801
#  401  1.000000
#  446  0.963577
#  491  0.891854
#  535  0.965608
#  581  0.980937,
#  'lHip_y_min':             m
#  14   0.000000
#  77   0.054481
#  124  0.002193
#  167  0.093003
#  208  0.160260
#  260  0.069545
#  313  0.019116
#  359  0.166648
#  403  0.174922
#  448  0.167671
#  485  0.368519
#  534  0.259690
#  580  0.141836,
#  'lHip_y_max':             m
#  8    0.644654
#  39   0.773807
#  88   0.681724
#  155  0.660924
#  183  0.704156
#  229  0.652238
#  275  0.742044
#  322  0.757247
#  365  0.872745
#  411  0.916328
#  434  0.867542
#  460  0.896267
#  499  0.848603
#  521  0.942152
#  553  1.000000
#  557  1.000000
#  558  1.000000
#  559  1.000000
#  590  0.890640,
#  'lHip_s_min':             m
#  14   0.649474
#  76   0.636274
#  131  0.638832
#  178  0.649181
#  217  0.650590
#  262  0.659978
#  307  0.641439
#  359  0.646648
#  402  0.631263
#  451  0.652790
#  490  0.637751
#  537  0.617795
#  576  0.597578,
#  'lHip_s_max':             m
#  10   0.766203
#  41   0.777700
#  88   0.780902
#  158  0.775145
#  182  0.768173
#  204  0.772959
#  231  0.768249
#  293  0.765470
#  321  0.781570
#  343  0.784226
#  387  0.771182
#  412  0.762626
#  434  0.775516
#  456  0.777269
#  477  0.779393
#  499  0.774050
#  546  0.772621
#  590  0.767115,
#  'rHip_y_min':             m
#  17   0.000000
#  76   0.044456
#  124  0.025559
#  167  0.116965
#  211  0.086673
#  260  0.095398
#  313  0.044645
#  336  0.213925
#  359  0.191093
#  403  0.199420
#  448  0.190041
#  474  0.347069
#  534  0.284744
#  580  0.168152,
#  'rHip_y_max':             m
#  10   0.658011
#  42   0.779298
#  85   0.590943
#  107  0.620261
#  160  0.666851
#  182  0.549219
#  204  0.631520
#  228  0.668276
#  277  0.669473
#  324  0.646876
#  385  0.792265
#  412  0.843928
#  460  0.898065
#  520  0.849848
#  551  1.000000
#  557  1.000000
#  558  1.000000
#  596  1.000000,
#  'rHip_s_min':             m
#  35   0.676881
#  81   0.684955
#  118  0.682812
#  173  0.667802
#  209  0.690370
#  270  0.689123
#  311  0.687002
#  357  0.694219
#  402  0.683249
#  467  0.693835
#  511  0.681772
#  554  0.684363
#  581  0.690405,
#  'rHip_s_max':             m
#  3    0.753858
#  42   0.772395
#  85   0.755099
#  140  0.767628
#  184  0.752803
#  230  0.754812
#  278  0.771877
#  336  0.755783
#  368  0.754936
#  412  0.751420
#  437  0.756706
#  458  0.756712
#  501  0.753175
#  548  0.746753
#  594  0.751587,
#  'lKnee_y_min':             m
#  0    0.000000
#  1    0.000000
#  2    0.000000
#  62   0.088767
#  110  0.107397
#  150  0.225015
#  171  0.224800
#  198  0.221758
#  234  0.096123
#  299  0.219115
#  334  0.225015
#  369  0.239958
#  427  0.365257
#  482  0.354317
#  517  0.453797
#  580  0.452354,
#  'lKnee_y_max':             m
#  6    0.358870
#  44   0.388019
#  86   0.503844
#  151  0.571191
#  184  0.497899
#  222  0.560894
#  284  0.675045
#  285  0.675045
#  323  0.671406
#  430  0.776856
#  460  0.952509
#  506  0.900057
#  510  0.900057
#  511  0.900057
#  512  0.900057
#  513  0.900057
#  543  1.000000
#  595  0.933306,
#  'lKnee_s_min':             m
#  37   0.778390
#  60   0.785183
#  106  0.772205
#  136  0.777449
#  172  0.780829
#  203  0.793644
#  230  0.783678
#  259  0.773107
#  301  0.784177
#  359  0.779783
#  389  0.780549
#  439  0.781540
#  465  0.794534
#  497  0.770245
#  523  0.766374
#  575  0.776572,
#  'lKnee_s_max':             m
#  0    0.875914
#  44   0.872411
#  99   0.852203
#  138  0.828986
#  187  0.857900
#  243  0.852640
#  289  0.853315
#  338  0.860419
#  381  0.853770
#  414  0.852697
#  455  0.830895
#  516  0.829708
#  548  0.846222
#  594  0.837814,
#  'rKnee_y_min':             m
#  28   0.000000
#  53   0.071891
#  116  0.153219
#  144  0.191877
#  145  0.191877
#  149  0.191877
#  150  0.191877
#  190  0.191877
#  191  0.191877
#  195  0.191877
#  196  0.191877
#  236  0.191877
#  237  0.191877
#  239  0.191877
#  260  0.197384
#  288  0.262951
#  336  0.293663
#  369  0.216932
#  414  0.311917
#  485  0.414879
#  517  0.472763
#  580  0.495349,
#  'rKnee_y_max':             m
#  6    0.362834
#  45   0.461251
#  46   0.461251
#  86   0.540715
#  155  0.559369
#  184  0.533422
#  222  0.628299
#  277  0.668791
#  310  0.658515
#  339  0.732369
#  411  0.773636
#  458  0.803147
#  497  0.822709
#  518  0.835625
#  558  1.000000
#  596  1.000000
#  597  1.000000,
#  'rKnee_s_min':             m
#  5    0.781893
#  53   0.781791
#  102  0.760752
#  152  0.775666
#  200  0.768330
#  232  0.768044
#  278  0.775105
#  325  0.764380
#  369  0.769031
#  428  0.767969
#  450  0.788777
#  473  0.787462
#  503  0.788547
#  536  0.782871
#  561  0.770388
#  593  0.778068,
#  'rKnee_s_max':             m
#  22   0.854879
#  62   0.828367
#  88   0.830665
#  139  0.840948
#  184  0.827340
#  230  0.829536
#  260  0.843806
#  301  0.841749
#  348  0.843370
#  391  0.842396
#  458  0.844674
#  515  0.831993
#  546  0.842368
#  596  0.852660,
#  'lAnkle_y_min':             m
#  0    0.045794
#  1    0.045794
#  2    0.045794
#  33   0.000000
#  60   0.038446
#  92   0.045794
#  93   0.045794
#  98   0.045794
#  148  0.045794
#  176  0.165036
#  243  0.115006
#  282  0.303253
#  286  0.303253
#  287  0.303253
#  329  0.303253
#  330  0.303253
#  331  0.303253
#  390  0.411338
#  428  0.409355
#  482  0.403773
#  521  0.548840
#  550  0.560713
#  551  0.560713
#  557  0.560713
#  558  0.560713,
#  'lAnkle_y_max':             m
#  12   0.311704
#  38   0.315055
#  89   0.392933
#  120  0.427160
#  178  0.427299
#  224  0.487549
#  281  0.560713
#  283  0.560713
#  284  0.560713
#  285  0.560713
#  325  0.612465
#  360  0.677647
#  383  0.688886
#  430  0.739962
#  498  0.830721
#  564  0.960983
#  591  1.000000,
#  'lAnkle_s_min':             m
#  33   0.793337
#  99   0.788848
#  205  0.781903
#  228  0.787623
#  274  0.789010
#  316  0.791912
#  361  0.769381
#  408  0.775338
#  452  0.776238
#  496  0.772847
#  568  0.771114,
#  'lAnkle_s_max':             m
#  7    0.837293
#  37   0.829308
#  58   0.838769
#  85   0.845768
#  110  0.848702
#  160  0.836398
#  224  0.825121
#  258  0.823680
#  299  0.835117
#  329  0.838046
#  374  0.833582
#  428  0.833931
#  475  0.832004
#  520  0.819645
#  547  0.820959
#  599  0.816305,
#  'rAnkle_y_min':             m
#  9    0.201164
#  43   0.000000
#  85   0.198607
#  142  0.207439
#  143  0.207439
#  144  0.207439
#  145  0.207439
#  146  0.207439
#  147  0.207439
#  148  0.207439
#  149  0.207439
#  150  0.207439
#  189  0.207439
#  190  0.207439
#  191  0.207439
#  192  0.207439
#  193  0.207439
#  194  0.207439
#  195  0.207439
#  196  0.207439
#  235  0.207439
#  236  0.207439
#  237  0.207439
#  238  0.207439
#  239  0.207439
#  240  0.207439
#  241  0.207439
#  283  0.207439
#  284  0.207439
#  285  0.207439
#  366  0.444263
#  390  0.384710
#  455  0.477809
#  495  0.444762
#  526  0.633772
#  567  0.522783,
#  'rAnkle_y_max':             m
#  31   0.467657
#  63   0.543640
#  104  0.589807
#  137  0.680526
#  177  0.639651
#  216  0.656854
#  295  0.742863
#  322  0.722388
#  365  0.754313
#  410  0.791147
#  434  0.799128
#  475  0.938420
#  519  0.941836
#  546  0.900402
#  591  1.000000,
#  'rAnkle_s_min':             m
#  3    0.809765
#  41   0.787147
#  83   0.792581
#  124  0.777145
#  164  0.781784
#  223  0.787824
#  257  0.782685
#  313  0.776744
#  346  0.784200
#  405  0.781747
#  429  0.777930
#  453  0.778001
#  495  0.777305
#  541  0.789910
#  564  0.787870,
#  'rAnkle_s_max':             m
#  24   0.848296
#  67   0.837952
#  105  0.843244
#  142  0.849278
#  200  0.847070
#  245  0.845425
#  288  0.846455
#  336  0.837490
#  381  0.845186
#  426  0.826406
#  471  0.837062
#  513  0.843417
#  551  0.833400
#  597  0.840963,
#  'rLowerLegLen_min':             m
#  4    0.371519
#  44   0.000000
#  85   0.256206
#  143  0.151985
#  188  0.109341
#  242  0.124249
#  283  0.151985
#  284  0.151985
#  285  0.151985
#  384  0.262329
#  411  0.142999
#  455  0.214185
#  479  0.179974
#  568  0.064361
#  596  0.171618
#  597  0.171618,
#  'rLowerLegLen_max':             m
#  28   0.965547
#  63   0.962533
#  109  0.809677
#  171  0.891946
#  216  0.953984
#  260  1.000000
#  369  0.907669
#  414  0.828705
#  474  0.848842
#  517  0.913102
#  580  0.949777,
#  'rLowerLegAng_min':              m
#  9   -87.999217
#  43  -90.045649
#  79  -88.135532
#  130 -88.069715
#  176 -88.135527
#  216 -88.197101
#  267 -88.135535
#  316 -86.229641
#  360 -88.135537
#  421 -87.753883
#  422 -87.753883
#  449 -86.098469
#  485 -86.229641
#  516 -87.923490
#  539 -86.098472
#  561 -87.923473
#  595 -87.841925,
#  'rLowerLegAng_max':              m
#  0   -85.644714
#  1   -85.644714
#  2   -85.644714
#  55  -85.807107
#  102 -85.644712
#  142 -85.469409
#  164 -84.332165
#  197 -85.644711
#  232 -85.807098
#  281 -85.644714
#  330 -83.460362
#  387 -83.927037
#  419 -83.460362
#  458 -83.460370
#  546 -83.702232
#  568 -83.702235
#  593 -83.927045,
#  'rLowerLegScr_min':             m
#  5    0.802277
#  44   0.798939
#  78   0.798669
#  125  0.789711
#  179  0.787362
#  210  0.788846
#  263  0.794056
#  325  0.793228
#  383  0.790830
#  429  0.788166
#  453  0.786934
#  491  0.792350
#  536  0.790471
#  570  0.788395
#  593  0.790203,
#  'rLowerLegScr_max':             m
#  21   0.849689
#  67   0.831164
#  105  0.835316
#  139  0.842886
#  194  0.836096
#  230  0.828337
#  251  0.832114
#  282  0.828553
#  329  0.828730
#  366  0.826461
#  409  0.829985
#  471  0.832599
#  519  0.830051
#  549  0.823783
#  596  0.841742,
#  'lLowerLegLen_min':             m
#  24   0.232028
#  86   0.242675
#  151  0.007750
#  184  0.247634
#  243  0.230595
#  277  0.325704
#  323  0.276176
#  382  0.369773
#  460  0.061241
#  512  0.100676
#  543  0.000000
#  588  0.327075,
#  'lLowerLegLen_max':             m
#  12   0.838818
#  62   0.835235
#  102  0.824047
#  126  0.727207
#  171  0.722238
#  234  0.853191
#  334  0.936275
#  369  1.000000
#  436  0.836539
#  483  0.852845
#  517  0.738317
#  567  0.826522
#  591  0.909038,
#  'lLowerLegAng_min':              m
#  2   -90.045649
#  4   -90.045649
#  6   -90.045649
#  35  -90.045649
#  38  -90.045649
#  ..         ...
#  589 -90.045649
#  591 -90.045649
#  592 -90.045649
#  598 -90.045649
#  599 -90.045649
#
#  [186 rows x 1 columns],
#  'lLowerLegAng_max':              m
#  17  -86.229636
#  49  -87.841940
#  50  -87.841940
#  75  -86.098452
#  148 -87.753872
#  189 -87.841940
#  191 -87.841940
#  230 -87.923487
#  278 -87.923471
#  328 -90.045649
#  382 -87.923472
#  406 -86.229636
#  471 -87.753866
#  511 -87.753873
#  557 -87.753884
#  558 -87.753884
#  595 -87.841913,
#  'lLowerLegScr_min':             m
#  30   0.797698
#  56   0.799723
#  106  0.800043
#  136  0.790373
#  170  0.791420
#  206  0.791320
#  230  0.792054
#  275  0.794382
#  309  0.797308
#  359  0.781487
#  400  0.791493
#  441  0.783859
#  496  0.773236
#  523  0.781481
#  575  0.779541,
#  'lLowerLegScr_max':             m
#  3    0.844661
#  46   0.841666
#  67   0.835743
#  130  0.827828
#  165  0.826634
#  243  0.830385
#  289  0.835423
#  338  0.845358
#  381  0.833496
#  414  0.830818
#  475  0.826605
#  519  0.816935
#  547  0.821729
#  594  0.819172,
#  'lUpperLegLen_min':             m
#  10   0.071832
#  41   0.000000
#  88   0.227101
#  109  0.254202
#  159  0.213984
#  183  0.127300
#  245  0.254212
#  275  0.098377
#  341  0.248184
#  365  0.041923
#  386  0.218506
#  411  0.010257
#  434  0.156095
#  462  0.304634
#  521  0.195278
#  559  0.093205
#  591  0.256636,
#  'lUpperLegLen_max':             m
#  20   0.766947
#  77   0.839140
#  120  0.920823
#  170  0.857800
#  222  0.806299
#  265  0.911040
#  311  1.000000
#  353  0.822689
#  403  0.958590
#  448  0.859103
#  474  0.719023
#  495  0.836731
#  534  0.911964
#  577  0.915390,
#  'lUpperLegAng_min':              m
#  18  -94.947226
#  81  -94.947219
#  143 -93.738915
#  144 -93.738915
#  145 -93.738915
#  147 -93.738915
#  148 -93.738915
#  150 -93.738915
#  183 -93.738908
#  225 -94.811718
#  255 -94.811706
#  278 -93.738909
#  302 -93.227095
#  365 -93.738914
#  433 -93.623800
#  456 -93.623776
#  478 -93.515639
#  501 -93.623800
#  564 -93.623800,
#  'lUpperLegAng_max':              m
#  3   -91.894191
#  62  -91.782244
#  92  -90.045649
#  131 -91.637586
#  170 -91.637588
#  237 -90.045649
#  239 -90.045649
#  241 -90.045649
#  282 -90.045649
#  284 -90.045649
#  285 -90.045649
#  286 -90.045649
#  287 -90.045649
#  308 -90.045649
#  309 -90.045649
#  310 -90.045649
#  326 -90.045649
#  327 -90.045649
#  328 -90.045649
#  329 -90.045649
#  330 -90.045649
#  331 -90.045649
#  332 -90.045649
#  333 -90.045649
#  334 -90.045649
#  335 -90.045649
#  336 -90.045649
#  337 -90.045649
#  348 -90.045649
#  350 -90.045649
#  372 -90.045649
#  374 -90.045649
#  378 -90.045649
#  379 -90.045649
#  385 -90.045649
#  414 -90.045649
#  415 -90.045649
#  416 -90.045649
#  462 -90.045649
#  463 -90.045649
#  464 -90.045649
#  468 -90.045649
#  469 -90.045649
#  476 -90.045649
#  506 -90.045649
#  512 -90.045649
#  513 -90.045649
#  534 -91.594584
#  592 -90.045649
#  598 -90.045649
#  599 -90.045649,
#  'lUpperLegScr_min':             m
#  24   0.723965
#  73   0.722230
#  132  0.711099
#  172  0.720121
#  219  0.728978
#  259  0.719172
#  307  0.714835
#  359  0.710102
#  403  0.711242
#  444  0.719408
#  490  0.708586
#  534  0.699911
#  576  0.683795,
#  'lUpperLegScr_max':             m
#  0    0.795536
#  44   0.820349
#  88   0.792191
#  158  0.790063
#  186  0.794985
#  243  0.797516
#  293  0.806879
#  323  0.817570
#  387  0.792085
#  412  0.797999
#  475  0.797982
#  519  0.793477
#  563  0.801798
#  589  0.792507,
#  'rUpperLegLen_min':             m
#  10   0.059663
#  41   0.000000
#  88   0.239731
#  109  0.229401
#  160  0.124447
#  183  0.258377
#  204  0.249238
#  232  0.288884
#  297  0.183588
#  320  0.264415
#  342  0.310786
#  364  0.099628
#  385  0.075814
#  431  0.182822
#  460  0.219309
#  520  0.195691
#  551  0.066332
#  557  0.066332
#  589  0.237055,
#  'rUpperLegLen_max':             m
#  14   0.762158
#  46   0.672734
#  76   0.751918
#  120  0.805894
#  167  0.716735
#  188  0.829482
#  211  0.744279
#  238  0.672734
#  265  0.796982
#  310  1.000000
#  357  0.728246
#  403  0.847385
#  448  0.761133
#  491  0.689549
#  534  0.804863
#  578  0.819145,
#  'rUpperLegAng_min':              m
#  37  -81.425631
#  76  -80.578528
#  102 -81.160481
#  164 -81.911416
#  210 -82.134481
#  253 -82.134475
#  304 -82.345693
#  363 -81.911421
#  388 -81.675524
#  431 -81.160492
#  494 -82.134475
#  546 -81.425641
#  585 -82.134464,
#  'rUpperLegAng_max':              m
#  9   -79.086024
#  43  -77.314839
#  92  -77.314833
#  149 -78.729977
#  176 -78.729976
#  216 -78.729982
#  243 -79.086023
#  286 -78.729977
#  329 -79.086028
#  372 -78.729977
#  373 -78.729977
#  375 -78.729977
#  405 -78.729973
#  472 -79.420596
#  514 -78.729977
#  515 -78.729977
#  561 -77.700311
#  599 -78.729977,
#  'rUpperLegScr_min':             m
#  14   0.748287
#  37   0.745703
#  81   0.743670
#  130  0.738114
#  173  0.732658
#  209  0.738624
#  253  0.744691
#  364  0.743916
#  402  0.750268
#  428  0.746675
#  470  0.744493
#  491  0.742830
#  554  0.739616
#  577  0.744983,
#  'rUpperLegScr_max':             m
#  42   0.796418
#  88   0.791517
#  140  0.795838
#  184  0.789192
#  230  0.791292
#  277  0.795349
#  324  0.781820
#  346  0.781018
#  367  0.791309
#  391  0.793003
#  437  0.794447
#  458  0.799484
#  519  0.789293
#  546  0.786335
#  596  0.796338,
#  'rBackLen_min':             m
#  33   0.095923
#  77   0.070316
#  125  0.083194
#  172  0.092435
#  211  0.092179
#  260  0.025809
#  312  0.022716
#  359  0.161797
#  399  0.033320
#  442  0.189306
#  491  0.176895
#  537  0.112570
#  580  0.000000,
#  'rBackLen_max':             m
#  10   0.681335
#  47   0.738472
#  89   0.613239
#  143  0.868238
#  146  0.868238
#  148  0.868238
#  194  0.738472
#  235  0.606773
#  240  0.606773
#  241  0.606773
#  284  0.868238
#  329  0.606773
#  330  0.606773
#  331  0.606773
#  335  0.606773
#  372  0.738473
#  373  0.738473
#  375  0.738473
#  417  0.870175
#  418  0.870175
#  420  0.870175
#  421  0.870175
#  422  0.870175
#  423  0.870175
#  424  0.870175
#  462  0.999999
#  463  0.999999
#  464  0.999999
#  467  0.999999
#  468  0.999999
#  469  0.999999
#  506  0.999999
#  510  0.999999
#  512  0.999999
#  513  0.999999
#  551  1.000000
#  557  1.000000
#  558  1.000000
#  597  0.870176
#  599  0.870176,
#  'rBackAng_min':              m
#  3   -93.623806
#  46  -91.894201
#  52  -91.894201
#  92  -93.623806
#  125 -91.894204
#  167 -93.623793
#  189 -93.623797
#  191 -93.623797
#  260 -93.738920
#  290 -91.894203
#  312 -91.894204
#  353 -93.623810
#  379 -93.738908
#  419 -91.782238
#  447 -91.836477
#  472 -91.836466
#  496 -91.782239
#  548 -91.836473
#  580 -91.894197,
#  'rBackAng_max':              m
#  4   -90.045649
#  6   -90.045649
#  9   -90.045649
#  10  -90.045649
#  11  -90.045649
#  ..         ...
#  589 -90.045649
#  590 -90.045649
#  591 -90.045649
#  593 -90.045649
#  598 -90.045649
#
#  [114 rows x 1 columns],
#  'rBackScr_min':             m
#  35   0.724966
#  83   0.723167
#  116  0.732650
#  173  0.731274
#  209  0.733752
#  271  0.727588
#  311  0.737056
#  357  0.733369
#  389  0.738650
#  453  0.745954
#  496  0.737096
#  538  0.740732
#  575  0.734076,
#  'rBackScr_max':             m
#  7    0.806749
#  42   0.807574
#  105  0.802810
#  139  0.793573
#  201  0.802884
#  230  0.806566
#  293  0.803192
#  323  0.807471
#  383  0.799522
#  457  0.795193
#  479  0.796037
#  519  0.790083
#  544  0.776665
#  565  0.776838
#  591  0.782174,
#  'lBackLen_min':             m
#  30   0.097825
#  77   0.075224
#  117  0.034167
#  172  0.098886
#  222  0.068246
#  265  0.008512
#  309  0.018591
#  359  0.041353
#  404  0.021337
#  447  0.090576
#  485  0.124818
#  534  0.013256
#  580  0.000000,
#  'lBackLen_max':             m
#  8    0.726216
#  42   0.809357
#  88   0.797292
#  154  0.786807
#  189  0.727800
#  192  0.727800
#  194  0.727800
#  243  0.633576
#  287  0.863858
#  332  0.727800
#  377  0.863858
#  425  0.863858
#  464  0.863858
#  514  1.000000
#  515  1.000000
#  553  0.999999
#  557  0.999999
#  558  0.999999
#  559  0.999999
#  596  0.863858
#  597  0.863858,
#  'lBackAng_min':              m
#  3   -82.917041
#  45  -83.130920
#  47  -83.130920
#  95  -82.917022
#  98  -82.917022
#  154 -81.911423
#  190 -82.917022
#  235 -82.917022
#  236 -82.917022
#  240 -82.917022
#  241 -82.917022
#  284 -83.130920
#  286 -83.130920
#  329 -83.130920
#  384 -83.522539
#  415 -83.130919
#  476 -81.675529
#  510 -83.522545
#  511 -83.522545
#  570 -81.911431
#  598 -83.332413
#  599 -83.332413,
#  'lBackAng_max':              m
#  31  -76.411730
#  77  -77.314826
#  120 -76.002277
#  176 -76.002279
#  217 -77.700293
#  260 -77.314820
#  313 -77.314838
#  359 -77.314837
#  397 -77.314833
#  447 -77.314841
#  492 -78.063430
#  534 -77.314836
#  582 -77.314837,
#  'lBackScr_min':             m
#  24   0.709721
#  78   0.720408
#  131  0.705986
#  176  0.719255
#  227  0.721917
#  270  0.722559
#  307  0.716328
#  359  0.720482
#  396  0.709650
#  451  0.717467
#  491  0.711546
#  534  0.689306
#  582  0.685781,
#  'lBackScr_max':             m
#  12   0.785736
#  41   0.794901
#  85   0.792189
#  158  0.797817
#  182  0.793425
#  204  0.784830
#  244  0.786645
#  281  0.788893
#  343  0.789837
#  373  0.787920
#  412  0.796582
#  434  0.796921
#  475  0.796025
#  499  0.798393
#  520  0.791129
#  546  0.797256
#  590  0.790594,
#  'mBackLen_min':             m
#  14   0.008071
#  77   0.148968
#  125  0.155976
#  174  0.196554
#  208  0.182510
#  238  0.067688
#  239  0.067688
#  265  0.030949
#  312  0.054762
#  359  0.088559
#  403  0.076944
#  447  0.179372
#  485  0.223531
#  534  0.204259
#  580  0.000000,
#  'mBackLen_max':             m
#  9    0.799070
#  42   0.845000
#  85   0.804562
#  107  0.784912
#  162  0.853267
#  228  0.640826
#  275  0.709396
#  297  0.683336
#  338  0.686157
#  372  0.809127
#  433  0.875837
#  460  0.957980
#  506  1.000000
#  513  1.000000
#  551  0.921447
#  596  0.728786,
#  'mBackAng_min':              m
#  19  -87.031334
#  44  -86.899105
#  90  -86.828535
#  126 -90.045646
#  192 -86.864209
#  243 -86.828537
#  279 -86.864210
#  348 -87.123443
#  379 -88.092147
#  437 -86.117748
#  464 -86.271454
#  468 -86.271454
#  514 -86.966636
#  571 -87.152908
#  599 -86.828543,
#  'mBackAng_max':              m
#  25  -84.631043
#  80  -84.742033
#  116 -84.156674
#  165 -83.946698
#  212 -83.572545
#  251 -83.905283
#  316 -83.572553
#  364 -84.742033
#  406 -83.702240
#  439 -83.887356
#  497 -83.826854
#  534 -84.631037
#  574 -84.742028,
#  'mBackScr_min':             m
#  17   0.762801
#  76   0.745608
#  131  0.751539
#  176  0.751839
#  209  0.753666
#  271  0.754940
#  307  0.739471
#  359  0.743714
#  403  0.737693
#  451  0.748318
#  492  0.749341
#  534  0.738922
#  582  0.716096,
#  'mBackScr_max':             m
#  8    0.853645
#  40   0.861380
#  88   0.859631
#  156  0.857543
#  204  0.863776
#  231  0.860540
#  292  0.845451
#  324  0.856756
#  385  0.847374
#  412  0.855882
#  433  0.856857
#  475  0.860913
#  520  0.863003
#  545  0.852427
#  591  0.844746,
#  'bodyLen_min':             m
#  3    0.219583
#  44   0.029838
#  110  0.201849
#  154  0.472015
#  240  0.000000
#  278  0.247227
#  319  0.148557
#  362  0.347703
#  384  0.309217
#  409  0.362037
#  454  0.452620
#  490  0.264463
#  533  0.456366
#  557  0.377988
#  587  0.208684,
#  'bodyLen_max':             m
#  16   0.511347
#  86   0.628952
#  162  0.902959
#  201  0.763246
#  231  0.594184
#  294  0.703847
#  348  0.765760
#  383  0.792899
#  429  0.934085
#  507  1.000000
#  546  0.925867
#  593  0.632737,
#  'bodyAng_min':              m
#  35  -87.018079
#  126 -88.254831
#  162 -86.766313
#  192 -86.957595
#  256 -87.057495
#  348 -86.794889
#  380 -86.987520
#  429 -86.335339
#  483 -86.499082
#  571 -86.780660,
#  'bodyAng_max':              m
#  25  -86.011805
#  83  -85.957963
#  116 -85.760598
#  165 -85.587788
#  212 -86.046918
#  282 -86.059315
#  322 -85.522397
#  406 -85.094805
#  439 -85.341209
#  490 -85.509557
#  531 -85.568482
#  563 -85.747629
#  596 -85.796650
#  597 -85.796650,
#  'bodykScr_min':             m
#  17   0.831655
#  47   0.830687
#  97   0.830027
#  169  0.829784
#  209  0.836447
#  236  0.816547
#  271  0.823928
#  307  0.830240
#  332  0.822463
#  359  0.818479
#  403  0.822735
#  442  0.814844
#  482  0.820481
#  527  0.822089
#  553  0.819251
#  580  0.805585,
#  'bodykScr_max':             m
#  8    0.887196
#  57   0.887489
#  85   0.897522
#  126  0.884736
#  156  0.883315
#  231  0.885389
#  279  0.878196
#  324  0.893585
#  368  0.879725
#  428  0.893049
#  475  0.891794
#  520  0.893925
#  545  0.878524
#  593  0.879706,
#  'in_min':      m
#  0  0.0,
#  'in_max':          m
#  599  599.0}

# %%
for i in min_max:
    for index in min_max[i].index:
        if min_max[i]['m'][index]<ref_mm[i]-10 or min_max[i]['m'][index]>ref_mm[i]+10:
            er['error'][index]=er['error'][index]+1

# %%
er['error'].value_counts()
# Out:
# 0    600
# Name: error, dtype: int64

# %%
gr=er[er['error']>2].index
gr
# Out:
# Int64Index([], dtype='int64')

# %%
from scipy.signal import argrelextrema
n=35
test['counts'] = test.iloc[argrelextrema(df.lElbow_y.values, np.greater_equal, order=n)[0]]['lElbow_y']
plt.scatter(test.index, test['counts'], c='b')
plt.plot(test.index, test['lElbow_y'])
plt.show()
b = test['counts'].count()
print('Count of reps:',b)
# Out:
# Count of reps: 13

# %%
import os
import cv2
def FrameCapture(path): 
      
    # Path to video file 
    vidObj = cv2.VideoCapture(path) 
    font = cv2.FONT_HERSHEY_SIMPLEX 
    # Used as counter variable 
    count = 0
    c=0
    # checks whether frames were extracted 
    success = 1
    #success, image = vidObj.read()
    while success: 
        # vidObj object calls read 
        # function extract frames 
        success, image = vidObj.read()
        if count in gr:
            c=c+10
        # Saves the frames with frame-count 
        if c>0:
            image = cv2.putText(image,'WRONG',(50, 50),font, 1,  
                (255, 0, 0),4, cv2.LINE_4)
#             image=cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
            c=c-1
        image1 = cv2.putText(image,'Count of reps:'+str(b),(50, 50),font, 1,  
                (255, 0, 0),4, cv2.LINE_4)
        cv2.imwrite("frame%d.jpg" % count, image1) 
        count += 1

FrameCapture("D:\Prith\Overhead press\over1.mp4")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-27-da8530b9ac67> in <module>
#      29         count += 1
#      30
# ---> 31 FrameCapture("D:\Prith\Overhead press\over1.mp4")
#
# <ipython-input-27-da8530b9ac67> in FrameCapture(path)
#      26         image1 = cv2.putText(image,'Count of reps:'+str(b),(50, 50),font, 1,
#      27                 (255, 0, 0),4, cv2.LINE_4)
# ---> 28         cv2.imwrite("frame%d.jpg" % count, image1)
#      29         count += 1
#      30
#
# error: OpenCV(4.4.0) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-6sxsq0tp\opencv\modules\imgcodecs\src\loadsave.cpp:738: error: (-215:Assertion failed) !_img.empty() in function 'cv::imwrite'

# %%
# Video Generating function 
def generate_video(): 
    image_folder = '.' # make sure to use your folder 
    video_name = 'test.mp4'
      
    images = [img for img in os.listdir(image_folder) 
              if img.endswith(".jpg") or
                 img.endswith(".jpeg") or
                 img.endswith("png")] 
     
    # Array images should only consider 
    # the image files ignoring others if any 
    print(images)  
  
    frame = cv2.imread(os.path.join(image_folder, images[0])) 
  
    # setting the frame width, height width 
    # the width, height of first image 
    height, width, layers = frame.shape   
  
    video = cv2.VideoWriter(video_name, 0, 60, (width, height))  
  
    # Appending the images to the video one by one 
    for image in images:  
        video.write(cv2.imread(os.path.join(image_folder, image)))  
      
    # Deallocating memories taken for window creation 
    cv2.destroyAllWindows()  
    video.release()  # releasing the video generated 
  
  
# Calling the generate_video function 
generate_video()
# Out:
# ['frame0.jpg', 'frame1.jpg', 'frame10.jpg', 'frame100.jpg', 'frame101.jpg', 'frame102.jpg', 'frame103.jpg', 'frame104.jpg', 'frame105.jpg', 'frame106.jpg', 'frame107.jpg', 'frame108.jpg', 'frame109.jpg', 'frame11.jpg', 'frame110.jpg', 'frame111.jpg', 'frame112.jpg', 'frame113.jpg', 'frame114.jpg', 'frame115.jpg', 'frame116.jpg', 'frame117.jpg', 'frame118.jpg', 'frame119.jpg', 'frame12.jpg', 'frame120.jpg', 'frame121.jpg', 'frame122.jpg', 'frame123.jpg', 'frame124.jpg', 'frame125.jpg', 'frame126.jpg', 'frame127.jpg', 'frame128.jpg', 'frame129.jpg', 'frame13.jpg', 'frame130.jpg', 'frame131.jpg', 'frame132.jpg', 'frame133.jpg', 'frame134.jpg', 'frame135.jpg', 'frame136.jpg', 'frame137.jpg', 'frame138.jpg', 'frame139.jpg', 'frame14.jpg', 'frame140.jpg', 'frame141.jpg', 'frame142.jpg', 'frame143.jpg', 'frame144.jpg', 'frame145.jpg', 'frame146.jpg', 'frame147.jpg', 'frame148.jpg', 'frame149.jpg', 'frame15.jpg', 'frame150.jpg', 'frame151.jpg', 'frame152.jpg', 'frame153.jpg', 'frame154.jpg', 'frame155.jpg', 'frame156.jpg', 'frame157.jpg', 'frame158.jpg', 'frame159.jpg', 'frame16.jpg', 'frame160.jpg', 'frame161.jpg', 'frame162.jpg', 'frame163.jpg', 'frame164.jpg', 'frame165.jpg', 'frame166.jpg', 'frame167.jpg', 'frame168.jpg', 'frame169.jpg', 'frame17.jpg', 'frame170.jpg', 'frame171.jpg', 'frame172.jpg', 'frame173.jpg', 'frame174.jpg', 'frame175.jpg', 'frame176.jpg', 'frame177.jpg', 'frame178.jpg', 'frame179.jpg', 'frame18.jpg', 'frame180.jpg', 'frame181.jpg', 'frame182.jpg', 'frame183.jpg', 'frame184.jpg', 'frame185.jpg', 'frame186.jpg', 'frame187.jpg', 'frame188.jpg', 'frame189.jpg', 'frame19.jpg', 'frame190.jpg', 'frame191.jpg', 'frame192.jpg', 'frame193.jpg', 'frame194.jpg', 'frame195.jpg', 'frame196.jpg', 'frame197.jpg', 'frame198.jpg', 'frame199.jpg', 'frame2.jpg', 'frame20.jpg', 'frame200.jpg', 'frame201.jpg', 'frame202.jpg', 'frame203.jpg', 'frame204.jpg', 'frame205.jpg', 'frame206.jpg', 'frame207.jpg', 'frame208.jpg', 'frame209.jpg', 'frame21.jpg', 'frame210.jpg', 'frame211.jpg', 'frame212.jpg', 'frame213.jpg', 'frame214.jpg', 'frame215.jpg', 'frame216.jpg', 'frame217.jpg', 'frame218.jpg', 'frame219.jpg', 'frame22.jpg', 'frame220.jpg', 'frame221.jpg', 'frame222.jpg', 'frame223.jpg', 'frame224.jpg', 'frame225.jpg', 'frame226.jpg', 'frame227.jpg', 'frame228.jpg', 'frame229.jpg', 'frame23.jpg', 'frame230.jpg', 'frame231.jpg', 'frame232.jpg', 'frame233.jpg', 'frame234.jpg', 'frame235.jpg', 'frame236.jpg', 'frame237.jpg', 'frame238.jpg', 'frame239.jpg', 'frame24.jpg', 'frame240.jpg', 'frame241.jpg', 'frame242.jpg', 'frame243.jpg', 'frame244.jpg', 'frame245.jpg', 'frame246.jpg', 'frame247.jpg', 'frame248.jpg', 'frame249.jpg', 'frame25.jpg', 'frame250.jpg', 'frame251.jpg', 'frame252.jpg', 'frame253.jpg', 'frame254.jpg', 'frame255.jpg', 'frame256.jpg', 'frame257.jpg', 'frame258.jpg', 'frame259.jpg', 'frame26.jpg', 'frame260.jpg', 'frame261.jpg', 'frame262.jpg', 'frame263.jpg', 'frame264.jpg', 'frame265.jpg', 'frame266.jpg', 'frame267.jpg', 'frame268.jpg', 'frame269.jpg', 'frame27.jpg', 'frame270.jpg', 'frame271.jpg', 'frame272.jpg', 'frame273.jpg', 'frame274.jpg', 'frame275.jpg', 'frame276.jpg', 'frame277.jpg', 'frame278.jpg', 'frame279.jpg', 'frame28.jpg', 'frame280.jpg', 'frame281.jpg', 'frame282.jpg', 'frame283.jpg', 'frame284.jpg', 'frame285.jpg', 'frame286.jpg', 'frame287.jpg', 'frame288.jpg', 'frame289.jpg', 'frame29.jpg', 'frame290.jpg', 'frame291.jpg', 'frame292.jpg', 'frame293.jpg', 'frame294.jpg', 'frame295.jpg', 'frame296.jpg', 'frame297.jpg', 'frame298.jpg', 'frame299.jpg', 'frame3.jpg', 'frame30.jpg', 'frame300.jpg', 'frame301.jpg', 'frame302.jpg', 'frame303.jpg', 'frame304.jpg', 'frame305.jpg', 'frame306.jpg', 'frame307.jpg', 'frame308.jpg', 'frame309.jpg', 'frame31.jpg', 'frame310.jpg', 'frame311.jpg', 'frame312.jpg', 'frame313.jpg', 'frame314.jpg', 'frame315.jpg', 'frame316.jpg', 'frame317.jpg', 'frame318.jpg', 'frame319.jpg', 'frame32.jpg', 'frame320.jpg', 'frame321.jpg', 'frame322.jpg', 'frame323.jpg', 'frame324.jpg' ...

# %% [raw]
# import glob
#
# frameSize = (500, 500)
#
# out = cv2.VideoWriter('output_video.mp4',cv2.VideoWriter_fourcc(*'MPG4'), 60, frameSize)
#
# for filename in glob.glob('D:\Prith\Lunges\Attempt1\*.jpg'):
#     img = cv2.imread(filename)
#     out.write(img)
#
# out.release()
